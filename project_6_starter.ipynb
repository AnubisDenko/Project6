# %% [markdown]
# # Project 6: Analyzing Stock Sentiment from Twits
# ## Instructions
# Each problem consists of a function to implement and instructions on how to implement the function.  The parts of the function that need to be implemented are marked with a `# TODO` comment.
#
# ## Packages
# When you implement the functions, you'll only need to you use the packages you've used in the classroom, like [Pandas](https://pandas.pydata.org/) and [Numpy](http://www.numpy.org/). These packages will be imported for you. We recommend you don't add any import statements, otherwise the grader might not be able to run your code.
#
# ### Load Packages

# %%
import json
import nltk
import os
import random
import re
import torch

from torch import nn, optim
import torch.nn.functional as F

# %% [markdown]
# ## Introduction
# When deciding the value of a company, it's important to follow the news. For example, a product recall or natural disaster in a company's product chain. You want to be able to turn this information into a signal. Currently, the best tool for the job is a Neural Network.
#
# For this project, you'll use posts from the social media site [StockTwits](https://en.wikipedia.org/wiki/StockTwits). The community on StockTwits is full of investors, traders, and entrepreneurs. Each message posted is called a Twit. This is similar to Twitter's version of a post, called a Tweet. You'll build a model around these twits that generate a sentiment score.
#
# We've collected a bunch of twits, then hand labeled the sentiment of each. To capture the degree of sentiment, we'll use a five-point scale: very negative, negative, neutral, positive, very positive. Each twit is labeled -2 to 2 in steps of 1, from very negative to very positive respectively. You'll build a sentiment analysis model that will learn to assign sentiment to twits on its own, using this labeled data.
#
# The first thing we should to do, is load the data.
#
# ## Import Twits
# ### Load Twits Data
# This JSON file contains a list of objects for each twit in the `'data'` field:
#
# ```
# {'data':
#   {'message_body': 'Neutral twit body text here',
#    'sentiment': 0},
#   {'message_body': 'Happy twit body text here',
#    'sentiment': 1},
#    ...
# }
# ```
#
# The fields represent the following:
#
# * `'message_body'`: The text of the twit.
# * `'sentiment'`: Sentiment score for the twit, ranges from -2 to 2 in steps of 1, with 0 being neutral.
#
#
# To see what the data look like by printing the first 10 twits from the list.

# %%
with open(os.path.join('..', '..', 'data', 'project_6_stocktwits', 'twits.json'), 'r') as f:
    twits = json.load(f)

print(twits['data'][:10])
# Out:
# [{'message_body': '$FITB great buy at 26.00...ill wait', 'sentiment': 2, 'timestamp': '2018-07-01T00:00:09Z'}, {'message_body': '@StockTwits $MSFT', 'sentiment': 1, 'timestamp': '2018-07-01T00:00:42Z'}, {'message_body': '#STAAnalystAlert for $TDG : Jefferies Maintains with a rating of Hold setting target price at USD 350.00. Our own verdict is Buy  http://www.stocktargetadvisor.com/toprating', 'sentiment': 2, 'timestamp': '2018-07-01T00:01:24Z'}, {'message_body': '$AMD I heard there’s a guy who knows someone who thinks somebody knows something - on StockTwits.', 'sentiment': 1, 'timestamp': '2018-07-01T00:01:47Z'}, {'message_body': '$AMD reveal yourself!', 'sentiment': 0, 'timestamp': '2018-07-01T00:02:13Z'}, {'message_body': '$AAPL Why the drop? I warren Buffet taking out his position?', 'sentiment': 1, 'timestamp': '2018-07-01T00:03:10Z'}, {'message_body': '$BA bears have 1 reason on 06-29 to pay more attention https://dividendbot.com?s=BA', 'sentiment': -2, 'timestamp': '2018-07-01T00:04:09Z'}, {'message_body': '$BAC ok good we&#39;re not dropping in price over the weekend, lol', 'sentiment': 1, 'timestamp': '2018-07-01T00:04:17Z'}, {'message_body': '$AMAT - Daily Chart, we need to get back to above 50.', 'sentiment': 2, 'timestamp': '2018-07-01T00:08:01Z'}, {'message_body': '$GME 3% drop per week after spike... if no news in 3 months, back to 12s... if BO, then bingo... what is the odds?', 'sentiment': -2, 'timestamp': '2018-07-01T00:09:03Z'}]

# %% [markdown]
# ### Length of Data
# Now let's look at the number of twits in dataset. Print the number of twits below.

# %%
"""print out the number of twits"""

# TODO Implement 
len(twits['data'])
# Out:
# 1548010

# %% [markdown]
# ### Split Message Body and Sentiment Score

# %%
messages = [twit['message_body'] for twit in twits['data']]
# Since the sentiment scores are discrete, we'll scale the sentiments to 0 to 4 for use in our network
sentiments = [twit['sentiment'] + 2 for twit in twits['data']]

# %% [markdown]
# ## Preprocessing the Data
# With our data in hand we need to preprocess our text. These twits are collected by filtering on ticker symbols where these are denoted with a leader $ symbol in the twit itself. For example,
#
# `{'message_body': 'RT @google Our annual look at the year in Google blogging (and beyond) http://t.co/sptHOAh8 $GOOG',
#  'sentiment': 0}`
#
# The ticker symbols don't provide information on the sentiment, and they are in every twit, so we should remove them. This twit also has the `@google` username, again not providing sentiment information, so we should also remove it. We also see a URL `http://t.co/sptHOAh8`. Let's remove these too.
#
# The easiest way to remove specific words or phrases is with regex using the `re` module. You can sub out specific patterns with a space:
#
# ```python
# re.sub(pattern, ' ', text)
# ```
# This will substitute a space with anywhere the pattern matches in the text. Later when we tokenize the text, we'll split appropriately on those spaces.

# %% [markdown]
# ### Pre-Processing

# %%
nltk.download('wordnet')
nltk.download('punkt')

from nltk.tokenize import word_tokenize

def preprocess(message):
    """
    This function takes a string as input, then performs these operations: 
        - lowercase
        - remove URLs
        - remove ticker symbols 
        - removes punctuation
        - tokenize by splitting the string on whitespace 
        - removes any single character tokens
    
    Parameters
    ----------
        message : The text message to be preprocessed.
        
    Returns
    -------
        tokens: The preprocessed text into tokens.
    """ 
    #TODO: Implement     
    # Lowercase the twit message
    text = message.lower()   
    
    # Replace URLs with a space in the message    
    text = re.sub(r'htt(p|ps):.*(\s|$)',' ', text)
    
    # Replace ticker symbols with a space. The ticker symbols are any stock symbol that starts with $.
    text = re.sub(r'\$[a-zA-Z0-9]*', ' ', text )
    
    # Replace StockTwits usernames with a space. The usernames are any word that starts with @.
    text = re.sub(r'@[a-zA-Z0-9]* ', ' ', text )
    
    # Replace everything not a letter with a space
    text = re.sub(r'[^a-zA-Z ]', ' ', text)
    
    # Tokenize by splitting the string on whitespace into a list of words
    tokens = word_tokenize(text)
    
    # Lemmatize words using the WordNetLemmatizer. You can ignore any word that is not longer than one character.
    wnl = nltk.stem.WordNetLemmatizer()
    tokens = [ wnl.lemmatize(w,pos='v') for w in tokens if len(w) > 1]

    return tokens
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ### Preprocess All the Twits
# Now we can preprocess each of the twits in our dataset. Apply the function `preprocess` to all the twit messages.

# %%
# TODO Implement
tokenized = [ preprocess(message) for message in messages ]

# %% [markdown]
# ### Bag of Words
# Now with all of our messages tokenized, we want to create a vocabulary and count up how often each word appears in our entire corpus. Use the [`Counter`](https://docs.python.org/3.1/library/collections.html#collections.Counter) function to count up all the tokens.

# %%
tokenized
# Out:
# [['great', 'buy', 'at', 'ill', 'wait'],
#  [],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'maintain',
#   'with',
#   'rat',
#   'of',
#   'hold',
#   'set',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'be',
#   'buy'],
#  ['hear',
#   'there',
#   'guy',
#   'who',
#   'know',
#   'someone',
#   'who',
#   'think',
#   'somebody',
#   'know',
#   'something',
#   'on',
#   'stocktwits'],
#  ['reveal', 'yourself'],
#  ['why', 'the', 'drop', 'warren', 'buffet', 'take', 'out', 'his', 'position'],
#  ['bear', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['ok',
#   'good',
#   'we',
#   're',
#   'not',
#   'drop',
#   'in',
#   'price',
#   'over',
#   'the',
#   'weekend',
#   'lol'],
#  ['daily', 'chart', 'we', 'need', 'to', 'get', 'back', 'to', 'above'],
#  ['drop',
#   'per',
#   'week',
#   'after',
#   'spike',
#   'if',
#   'no',
#   'news',
#   'in',
#   'months',
#   'back',
#   'to',
#   'if',
#   'bo',
#   'then',
#   'bingo',
#   'what',
#   'be',
#   'the',
#   'odds'],
#  ['strong', 'buy'],
#  ['short', 'ratio', 'be', 'at', 'and', 'short', 'to', 'float', 'be'],
#  ['price',
#   'squeeze',
#   'perfect',
#   'place',
#   'for',
#   'an',
#   'option',
#   'straddle',
#   'near',
#   'the',
#   'support',
#   'trend'],
#  ['start',
#   'of',
#   'new',
#   'on',
#   'monday',
#   'expect',
#   'strong',
#   'buy',
#   'volume',
#   'across',
#   'key',
#   'company',
#   'of',
#   'various',
#   'sectors'],
#  ['breakout', 'strategy', 'current', 'portfolio'],
#  ['bull', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['catalysts',
#   'continue',
#   'this',
#   'new',
#   'uptrend',
#   'pill',
#   'pack',
#   'buy',
#   'out',
#   'amazon',
#   'prime',
#   'day',
#   'earn',
#   'test',
#   'break',
#   'of',
#   'soon'],
#  ['have',
#   'move',
#   'on',
#   'check',
#   'out',
#   'the',
#   'movement',
#   'and',
#   'peer',
#   'at'],
#  ['staanalystalert',
#   'for',
#   'mkm',
#   'partner',
#   'set',
#   'price',
#   'target',
#   'with',
#   'rat',
#   'of',
#   'buy',
#   'set',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'be',
#   'buy'],
#  ['think',
#   'it',
#   'be',
#   'too',
#   'early',
#   'to',
#   'tell',
#   'what',
#   'go',
#   'to',
#   'happen',
#   'monday',
#   'even',
#   'with',
#   'the',
#   'current',
#   'news',
#   'about',
#   'raisinf',
#   'output',
#   'there',
#   'be',
#   'still',
#   'so',
#   'many'],
#  ['have',
#   'current',
#   'ratio',
#   'of',
#   'so',
#   'it',
#   'be',
#   'financially',
#   'healthy',
#   'and',
#   'have',
#   'no',
#   'problem',
#   'in',
#   'meet',
#   'its',
#   'obligations'],
#  ['bullish', 'stock', 'to', 'watch', 'setups', 'timeframes'],
#  ['just', 'short', 'it'],
#  ['high', 'alert', 'for', 'next', 'week', 'gt', 'breakdown'],
#  ['the',
#   'current',
#   'ratio',
#   'of',
#   'be',
#   'much',
#   'better',
#   'than',
#   'the',
#   'industry',
#   'average',
#   'of'],
#  ['miss', 'these', 'days'],
#  ['if',
#   'break',
#   'and',
#   'confirm',
#   'next',
#   'week',
#   'you',
#   'will',
#   'see',
#   'violent',
#   'move',
#   'downward',
#   'to',
#   'my',
#   'buy',
#   'price'],
#  ['bear', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['breakouts',
#   'base',
#   'gap',
#   'and',
#   'day',
#   'ma',
#   'gap',
#   'gap',
#   'gap',
#   'and',
#   'day',
#   'ma'],
#  ['cabot',
#   'weekly',
#   'video',
#   'quot',
#   'resilient',
#   'growth',
#   'stock',
#   'to',
#   'watch',
#   'quot'],
#  ['when',
#   'be',
#   'kid',
#   'my',
#   'froend',
#   'tell',
#   'me',
#   'the',
#   'moon',
#   'be',
#   'make',
#   'out',
#   'of',
#   'cheese'],
#  ['short',
#   'volume',
#   'percent',
#   'for',
#   'be',
#   'on',
#   'and',
#   'day',
#   'rank',
#   'be',
#   'th',
#   'percentile'],
#  ['thank',
#   'you',
#   'don',
#   'feel',
#   'the',
#   'need',
#   'to',
#   'tell',
#   'or',
#   'to',
#   'do',
#   'well',
#   'for',
#   'me',
#   'they',
#   'already',
#   'have'],
#  ['during',
#   'the',
#   'youtube',
#   'interview',
#   'mitch',
#   'couldn',
#   'remember',
#   'single',
#   'movie',
#   'he',
#   'watch',
#   'all',
#   'year',
#   'except',
#   'star',
#   'war',
#   'black',
#   'panther',
#   'clothe'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'downgrade',
#   'with',
#   'rat',
#   'of',
#   'hold',
#   'set',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'be',
#   'hold'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'on', 'be'],
#  ['have',
#   'better',
#   'return',
#   'on',
#   'equity',
#   'than',
#   'the',
#   'industry',
#   'average',
#   'of'],
#  ['although',
#   'the',
#   'market',
#   'be',
#   'up',
#   'be',
#   'do',
#   'even',
#   'better',
#   'it',
#   'have',
#   'advance',
#   'as',
#   'of',
#   'more',
#   'info',
#   'peer',
#   'at'],
#  ['july',
#   'will',
#   'be',
#   'the',
#   'most',
#   'bullish',
#   'day',
#   'of',
#   'the',
#   'year',
#   'for',
#   'stock'],
#  ['option',
#   'volume',
#   'be',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'be',
#   'and',
#   'put',
#   'volume',
#   'be'],
#  ['third', 'design', 'win', 'the', 'time', 'match', 'it', 'probably', 'arm'],
#  ['alcohol',
#   'stock',
#   'tobacco',
#   'stock',
#   'and',
#   'firearm',
#   'stock',
#   'to',
#   'buy'],
#  ['president',
#   'trump',
#   'tweet',
#   'just',
#   'speak',
#   'to',
#   'king',
#   'salman',
#   'of',
#   'saudi',
#   'arabia',
#   'and',
#   'explain',
#   'to',
#   'him',
#   'that',
#   'because',
#   'of',
#   'the',
#   'turmoil',
#   'amp'],
#  ['today', 'insight', 'on'],
#  ['intc',
#   'mama',
#   'say',
#   'get',
#   'ice',
#   'cream',
#   'if',
#   'finish',
#   'my',
#   'due',
#   'dil'],
#  ['just',
#   'notice',
#   'they',
#   'have',
#   'the',
#   'last',
#   'jedi',
#   'on',
#   'stream',
#   'love',
#   'this',
#   'stock'],
#  ['here', 'you', 'go', 'will', 'just', 'leave', 'this', 'here'],
#  ['good',
#   'view',
#   'daily',
#   'still',
#   'look',
#   'good',
#   'ema',
#   'hold',
#   'above',
#   'ema',
#   'and',
#   'stochastics',
#   'turn',
#   'healthy',
#   'as',
#   'spy',
#   'qqq',
#   'opposite'],
#  ['with',
#   'forward',
#   'pe',
#   'of',
#   'the',
#   'valuation',
#   'of',
#   'can',
#   'be',
#   'describe',
#   'as',
#   'cheap'],
#  ['saber',
#   'capital',
#   'presentation',
#   'common',
#   'denominator',
#   'of',
#   'tencent',
#   'facebook',
#   'and',
#   'google'],
#  ['how', 'expect', 'the', 'earn'],
#  ['be',
#   'one',
#   'of',
#   'the',
#   'better',
#   'perform',
#   'stock',
#   'in',
#   'the',
#   'crude',
#   'petroleum',
#   'and',
#   'natural',
#   'gas',
#   'industry'],
#  ['pu',
#   'it',
#   'simply',
#   'havent',
#   'lose',
#   'on',
#   'any',
#   'brown',
#   'guy',
#   'run',
#   'tech',
#   'company',
#   'mfs',
#   'be',
#   'well',
#   'educate',
#   'know',
#   'their',
#   'shit',
#   'more',
#   'more',
#   'every',
#   'year'],
#  ['former',
#   'president',
#   'of',
#   'global',
#   'manufacture',
#   'at',
#   'pfizer',
#   'be',
#   'an',
#   'independent',
#   'director',
#   'at',
#   'nat',
#   'ricciardi'],
#  ['may', 'be', 'the', 'safest', 'stock', 'own'],
#  ['special',
#   'limit',
#   'offer',
#   'june',
#   'th',
#   'june',
#   'th',
#   'tradenet',
#   'be',
#   'offer',
#   'discount',
#   'on',
#   'intro',
#   'program'],
#  ['below', 'buy', 'put', 'on', 'financials'],
#  ['great',
#   'summary',
#   'of',
#   'jeff',
#   'gundlach',
#   'sohn',
#   'presentation',
#   'long',
#   'thesis',
#   'for',
#   'energy',
#   'stock'],
#  ['low',
#   'peg',
#   'ratio',
#   'which',
#   'compensate',
#   'the',
#   'pe',
#   'for',
#   'growth',
#   'indicate',
#   'rather',
#   'cheap',
#   'valuation'],
#  ['great',
#   'summary',
#   'of',
#   'jeff',
#   'gundlach',
#   'sohn',
#   'pres',
#   'long',
#   'thesis',
#   'for',
#   'energy',
#   'equities'],
#  ['come'],
#  ['seem', 'be', 'the', 'support', 'next', 'if', 'under', 'be', 'likely'],
#  ['have',
#   'move',
#   'on',
#   'check',
#   'out',
#   'the',
#   'movement',
#   'and',
#   'peer',
#   'at'],
#  ['bullshit',
#   'worthless',
#   'mean',
#   'fuck',
#   'nothing',
#   'this',
#   'be',
#   'macau',
#   'not',
#   'fuck',
#   'usa'],
#  ['take',
#   'this',
#   'let',
#   'me',
#   'know',
#   'where',
#   'be',
#   'we',
#   'right',
#   'now',
#   'lol'],
#  ['the',
#   'chart',
#   'look',
#   'so',
#   'ugly',
#   'without',
#   'clear',
#   'support',
#   'level',
#   'short',
#   'term',
#   'bearish',
#   'll',
#   'buy',
#   'when',
#   'this',
#   'be',
#   'at'],
#  ['great',
#   'summary',
#   'of',
#   'jeff',
#   'gundlach',
#   'sohn',
#   'presentation',
#   'long',
#   'thesis',
#   'for',
#   'energy',
#   'stock'],
#  ['previously',
#   'there',
#   'be',
#   'mo',
#   'run',
#   'up',
#   'follow',
#   'by',
#   'drop',
#   'we',
#   'be',
#   'at',
#   'the',
#   'end',
#   'of',
#   'month',
#   'of',
#   'another',
#   'runup',
#   'and',
#   'have',
#   'drop',
#   'about'],
#  ['smart', 'money', 'bet', 'on', 'call', 'deal', 'update'],
#  ['although',
#   'the',
#   'technical',
#   'rat',
#   'be',
#   'bad',
#   'do',
#   'present',
#   'nice',
#   'setup',
#   'opportunity'],
#  ['will',
#   'completely',
#   'scale',
#   'out',
#   'in',
#   'time',
#   'to',
#   'gobble',
#   'up',
#   'my',
#   'next',
#   'long',
#   'play',
#   'aka',
#   'my',
#   'favorite',
#   'gt'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'be'],
#  ['them', 'be', 'iddy', 'bitty', 'kiddy', 'hand'],
#  ['short',
#   'interest',
#   'ratio',
#   'of',
#   'be',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'be'],
#  ['then',
#   'awesome',
#   'it',
#   'be',
#   'now',
#   'be',
#   'concern',
#   'if',
#   'not',
#   'over',
#   'by',
#   'eow',
#   'might',
#   'get',
#   'under',
#   'next',
#   'wk',
#   'or',
#   'soon'],
#  ['throwback'],
#  ['staanalystalert',
#   'for',
#   'us',
#   'capital',
#   'advisors',
#   'upgrade',
#   'with',
#   'rat',
#   'of',
#   'hold',
#   'our',
#   'own',
#   'verdict',
#   'be',
#   'buy'],
#  ['lol',
#   'all',
#   'these',
#   'shorties',
#   'be',
#   'dream',
#   'of',
#   'great',
#   'depression',
#   'or',
#   'somethin',
#   'loll'],
#  ['just',
#   'update',
#   'hormel',
#   'foods',
#   'dividend',
#   'king',
#   'stock',
#   'analysis',
#   'dividend',
#   'king',
#   'consumer',
#   'defensive'],
#  ['today', 'insight', 'on'],
#  ['just',
#   'update',
#   'intel',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividends',
#   'technology'],
#  ['today', 'insight', 'on'],
#  ['the',
#   'long',
#   'and',
#   'short',
#   'term',
#   'trend',
#   'be',
#   'both',
#   'positive',
#   'this',
#   'be',
#   'look',
#   'good'],
#  ['they', 'so', 'mad', 'at', 'me', 'still'],
#  ['back', 'to', 'by', 'july'],
#  ['report', 'and', 'block', 'this', 'person', 'spam'],
#  ['should', 'open', 'at', 'on', 'monday'],
#  ['my',
#   'projection',
#   'for',
#   'if',
#   'thats',
#   'true',
#   'under',
#   'be',
#   'next',
#   'week',
#   'thats',
#   'why',
#   'prefer',
#   'to',
#   'buy',
#   'from',
#   'support',
#   'level'],
#  ['what', 'turd'],
#  ['percent', 'short', 'volume', 'for', 'be', 'on'],
#  ['wal',
#   'mart',
#   'dividend',
#   'aristocrat',
#   'dividend',
#   'aristocrat',
#   'consumer',
#   'defensive',
#   'valueinvesting',
#   'dvb',
#   'aaamp'],
#  ['look',
#   'for',
#   'marriage',
#   'have',
#   'in',
#   'my',
#   'bank',
#   'account',
#   'with',
#   'in',
#   'stock',
#   'dm'],
#  ['short', 'ratio', 'be', 'at', 'and', 'short', 'to', 'float', 'be'],
#  ['to',
#   'that',
#   'bear',
#   'that',
#   'win',
#   'stop',
#   'post',
#   'hold',
#   'big',
#   'short',
#   'position',
#   'over',
#   'weekend',
#   'calm',
#   'down',
#   'and',
#   'good',
#   'luck',
#   'lol'],
#  ['the',
#   'chase',
#   'continue',
#   'hopefully',
#   'they',
#   'catch',
#   'him',
#   'before',
#   'lisa',
#   'announce',
#   'the',
#   'rd',
#   'win'],
#  ['the',
#   'price',
#   'earn',
#   'ratio',
#   'be',
#   'which',
#   'indicate',
#   'rather',
#   'cheap',
#   'valuation',
#   'of'],
#  ['permamently',
#   'turn',
#   'me',
#   'off',
#   'of',
#   'option',
#   'trade',
#   'and',
#   'maybe',
#   'stock',
#   'altogether',
#   'manipulation',
#   'by',
#   'very',
#   'rich',
#   'to',
#   'make',
#   'me',
#   'very',
#   'poor',
#   'fuk',
#   'it'],
#  ['be',
#   'down',
#   'almost',
#   'pct',
#   'from',
#   'its',
#   'week',
#   'high',
#   'it',
#   'about',
#   'time',
#   'for',
#   'buybacks',
#   'get',
#   'more',
#   'share',
#   'in',
#   'my',
#   'account',
#   'though',
#   'from',
#   'drip'],
#  ['option',
#   'volume',
#   'be',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'be',
#   'and',
#   'put',
#   'volume',
#   'be'],
#  [],
#  ['dump',
#   'call',
#   'friday',
#   'at',
#   'open',
#   'that',
#   'be',
#   'obv',
#   'but',
#   'jeez',
#   'bite',
#   'over',
#   'do',
#   'here'],
#  ['bounce',
#   'off',
#   'support',
#   'heikin',
#   'ashi',
#   'weekly',
#   'candle',
#   'look',
#   'good',
#   'as',
#   'well',
#   'will',
#   'be',
#   'look',
#   'for',
#   'confirmation'],
#  ['like', 'this'],
#  ['look',
#   'for',
#   'wife',
#   'get',
#   'about',
#   'tree',
#   'fiddy',
#   'in',
#   'stock',
#   'and',
#   'it',
#   'sure',
#   'my',
#   'piggy',
#   'bank',
#   'have',
#   'get',
#   'lot',
#   'of',
#   'coin',
#   'may',
#   'spend',
#   'on',
#   'candy',
#   'no',
#   'dm',
#   'though'],
#  ['short',
#   'interest',
#   'ratio',
#   'be',
#   'on',
#   'and',
#   'short',
#   'to',
#   'float',
#   'be'],
#  ['just',
#   'update',
#   'microsoft',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividends',
#   'technology'],
#  ['bearish', 'investors', 'aren', 'happy', 'today', 'for', 'as', 'of'],
#  ['staanalystalert',
#   'for',
#   'royal',
#   'bank',
#   'of',
#   'canada',
#   'reiterate',
#   'with',
#   'rat',
#   'of',
#   'outperform',
#   'our',
#   'own',
#   'verdict',
#   'be',
#   'buy'],
#  ['staanalystalert',
#   'for',
#   'loop',
#   'capital',
#   'raise',
#   'target',
#   'with',
#   'rat',
#   'of',
#   'buy',
#   'set',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'be',
#   'buy'],
#  ['kid', 'never', 'be', 'wrong', 'he', 'miracle'],
#  ['what', 'be', 'period', 'bollinger', 'band', 'mean'],
#  ['you',
#   'dare',
#   'say',
#   'didn',
#   'know',
#   'you',
#   'be',
#   'as',
#   'guilty',
#   'as',
#   'fudge'],
#  ['today', 'insight', 'on'],
#  ['hardly',
#   'ever',
#   'an',
#   'informative',
#   'comment',
#   'here',
#   'and',
#   'the',
#   'page',
#   'be',
#   'break',
#   'give',
#   'endless',
#   'buffer',
#   'icon',
#   'give',
#   'up',
#   'stocktwits'],
#  ['viral',
#   'walk',
#   'away',
#   'videos',
#   'highlight',
#   'grow',
#   'movement',
#   'of',
#   'democrats',
#   'leave',
#   'the',
#   'party',
#   'the',
#   'epoch',
#   'time'],
#  ['staanalystalert',
#   'for',
#   'robert',
#   'baird',
#   'downgrade',
#   'with',
#   'rat',
#   'of',
#   'neutral',
#   'set',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'be',
#   'buy'],
#  ['too', 'much', 'weed', 'and', 'other', 'drug', 'guess'],
#  ['with',
#   'forward',
#   'pe',
#   'of',
#   'the',
#   'valuation',
#   'of',
#   'can',
#   'be',
#   'describe',
#   'as',
#   'very',
#   'reasonable'],
#  ['the',
#   'reason',
#   'nike',
#   'be',
#   'win',
#   'be',
#   'because',
#   'of',
#   'their',
#   'click',
#   'book',
#   'app',
#   'it',
#   'better',
#   'than',
#   'native',
#   'seamless',
#   'lovalized',
#   'transactable',
#   'ap'],
#  ['vitiello', 'tap', 'as', 'act', 'ice', 'director', 'via'],
#  ['will',
#   'reach',
#   'over',
#   'this',
#   'year',
#   'iconic',
#   'brand',
#   'global',
#   'technology',
#   'and',
#   'build',
#   'for',
#   'mobile',
#   'win',
#   'strategy',
#   'amp',
#   'show',
#   'in',
#   'earn'],
#  ['by', 'monday', 'morning'],
#  ['this', 'be', 'head', 'to', 'ath', 'soon', 'maybe', 'next', 'week'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'downgrade',
#   'with',
#   'rat',
#   'of',
#   'hold',
#   'set',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'be',
#   'buy'],
#  ['staanalystalert',
#   'for',
#   'baird',
#   'downgrade',
#   'with',
#   'rat',
#   'of',
#   'neutral',
#   'our',
#   'own',
#   'verdict',
#   'be',
#   'buy'],
#  ['there',
#   'have',
#   'be',
#   'acquisition',
#   'for',
#   'total',
#   'of',
#   'share',
#   'over',
#   'the',
#   'past',
#   'week',
#   'for'],
#  ['happy', 'trade', 'guy', 'look', 'to', 'exit', 'today'],
#  ['buy', 'zone'],
#  [],
#  ['fantastic',
#   'read',
#   'oil',
#   'market',
#   'continue',
#   'to',
#   'tighten',
#   'bbl',
#   'be',
#   'get',
#   'closer'],
#  ['one', 'of', 'the', 'greatest', 'buy'],
#  ['look',
#   'at',
#   'the',
#   'yearly',
#   'performance',
#   'do',
#   'better',
#   'than',
#   'of',
#   'all',
#   'other',
#   'stock'],
#  ['at',
#   'amp',
#   'dividend',
#   'aristocrat',
#   'dividends',
#   'aristocrat',
#   'champion',
#   'cashflow',
#   'highyield',
#   'telecommunications',
#   'dividend'],
#  ['that',
#   'pretty',
#   'risky',
#   'gamble',
#   'no',
#   'the',
#   'stock',
#   'can',
#   'either',
#   'plummet',
#   'or',
#   'rally'],
#  ['the',
#   'short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'be'],
#  ['stronger'],
#  ['apple',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividend',
#   'technology',
#   'dividends'],
#  ['not', 'talk', 'about', 'be', 'refer', 'to', 'intelsat'],
#  ['will',
#   'punish',
#   'sellers',
#   'who',
#   'don',
#   'move',
#   'stock',
#   'from',
#   'its',
#   'warehouse',
#   'common',
#   'sense',
#   'old',
#   'gather',
#   'dust',
#   'new',
#   'gather',
#   'money'],
#  ['pc',
#   'gamers',
#   'crypto',
#   'miners',
#   'and',
#   'other',
#   'gpu',
#   'enthusiasts',
#   'have',
#   'be',
#   'wait',
#   'over',
#   'two',
#   'years',
#   'for',
#   'the',
#   'company',
#   'next',
#   'big'],
#  ['have',
#   'only',
#   'medium',
#   'technical',
#   'rat',
#   'but',
#   'it',
#   'do',
#   'show',
#   'decent',
#   'setup',
#   'pattern'],
#  ['today', 'insight', 'on'],
#  ['what', 'will', 'be', 'more', 'in', 'five', 'years', 'baba', 'or', 'apple'],
#  ['next', 'week', 'ahhhhhhhhhhhhhhhhhhhhh'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'be'],
#  ['raytheon',
#   'valuation',
#   'profitability',
#   'and',
#   'dividend',
#   'safety',
#   'score',
#   'analysis',
#   'dividends',
#   'industrials',
#   'military'],
#  ['why', 'we', 'trend'],
#  ['we',
#   'will',
#   'get',
#   'riiiiiiiiiich',
#   'sooooon',
#   'buuuuls',
#   'looooove',
#   'you',
#   'all',
#   'and',
#   'fuck',
#   'drink'],
#  ['if',
#   'this',
#   'doesn',
#   'get',
#   'through',
#   'it',
#   'go',
#   'to',
#   'make',
#   'new',
#   'low',
#   'when',
#   'it',
#   'pay',
#   'the',
#   'dividend'],
#  ['gap', 'up', 'monday'],
#  ['short', 'ratio', 'of', 'be', 'at', 'and', 'short', 'to', 'float', 'be'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'maintain',
#   'with',
#   'rat',
#   'of',
#   'hold',
#   'set',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'be',
#   'buy'],
#  ['should',
#   'by',
#   'warbey',
#   'parker',
#   'for',
#   'in',
#   'prep',
#   'for',
#   'apple',
#   'glass',
#   'as',
#   'see',
#   'with',
#   'watch',
#   'apple',
#   'focus',
#   'on',
#   'fashion',
#   'and',
#   'tech',
#   'wrt',
#   'wearables'],
#  ['look',
#   'like',
#   'sbux',
#   'be',
#   'pay',
#   'full',
#   'sex',
#   'change',
#   'for',
#   'employees',
#   'now',
#   'that',
#   'll',
#   'hit',
#   'the',
#   'bottom',
#   'line'],
#  ['weekly',
#   'recap',
#   'price',
#   'move',
#   'since',
#   'post',
#   'expect',
#   'run',
#   'up',
#   'to',
#   'other',
#   'trade',
#   'include',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn',
#   'akam'],
#  ['enterprise',
#   'value',
#   'vs',
#   'market',
#   'cap',
#   'difference',
#   'of',
#   'actual',
#   'assets',
#   'vs',
#   'market',
#   'value',
#   'too',
#   'big',
#   'spread',
#   'way',
#   'undervalue'],
#  ['million', 'share', 'add', 'on', 'june', 'dont', 'wait'],
#  ['who',
#   'think',
#   'amazon',
#   'will',
#   'become',
#   'such',
#   'monopoly',
#   'dip',
#   'into',
#   'everything',
#   'that',
#   'an',
#   'amazon',
#   'airline',
#   'be',
#   'possibility',
#   'do'],
#  ['don',
#   'miss',
#   'the',
#   'breakout',
#   'on',
#   'buy',
#   'stop',
#   'stop',
#   'loss',
#   'be',
#   'suggest',
#   'by',
#   'the',
#   'chartmill',
#   'analyzer'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'on', 'be'],
#  ['weekly',
#   'recap',
#   'price',
#   'have',
#   'move',
#   'since',
#   'post',
#   'support',
#   'resistance',
#   'other',
#   'trade',
#   'include',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn',
#   'akam',
#   'len'],
#  ['weekly',
#   'recap',
#   'price',
#   'have',
#   'move',
#   'since',
#   'post',
#   'reversal',
#   'in',
#   'progress',
#   'other',
#   'trade',
#   'include',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn',
#   'akam',
#   'len',
#   'hsy'],
#  ['ve',
#   'recently',
#   'close',
#   'my',
#   'position',
#   'in',
#   'for',
#   'now',
#   'be',
#   'probably',
#   'next',
#   'on',
#   'the',
#   'list',
#   'buy',
#   'both',
#   'in',
#   'the',
#   'same',
#   'week'],
#  ['nat',
#   'ricciardi',
#   'be',
#   'director',
#   'use',
#   'to',
#   'be',
#   'president',
#   'of',
#   'global',
#   'manufacture'],
#  ['accord',
#   'to',
#   'data',
#   'report',
#   'to',
#   'finra',
#   'short',
#   'volume',
#   'percent',
#   'for',
#   'clock',
#   'in',
#   'at',
#   'on'],
#  ['saudi',
#   'officials',
#   'come',
#   'out',
#   'say',
#   'they',
#   'didn',
#   'agree',
#   'to',
#   'this'],
#  ['weekly',
#   'recap',
#   'price',
#   'move',
#   'since',
#   'post',
#   'uptrend',
#   'to',
#   'resume',
#   'other',
#   'trade',
#   'include',
#   'kmx',
#   'wynn',
#   'akam',
#   'len',
#   'hsy',
#   'uri',
#   'sonc'],
#  ['the',
#   'one',
#   'on',
#   'the',
#   'right',
#   'cover',
#   'the',
#   'penis',
#   'or',
#   'the',
#   'putang',
#   'the',
#   'front',
#   'legs',
#   'would',
#   'be',
#   'arm'],
#  [],
#  ['some', 'of', 'the', 'stock', 'be', 'watch', 'now'],
#  ['short', 'ratio', 'of', 'be', 'at', 'and', 'short', 'to', 'float', 'be'],
#  ['weekly',
#   'recap',
#   'price',
#   'move',
#   'since',
#   'post',
#   'next',
#   'stop',
#   'other',
#   'trade',
#   'include',
#   'wynn',
#   'akam',
#   'len',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri'],
#  ['wonder',
#   'how',
#   'much',
#   'this',
#   'will',
#   'be',
#   'value',
#   'at',
#   'in',
#   'years',
#   'we',
#   'be',
#   'not',
#   'even',
#   'in',
#   'the',
#   'th',
#   'inning'],
#  ['have',
#   'bad',
#   'technical',
#   'rat',
#   'but',
#   'it',
#   'do',
#   'show',
#   'decent',
#   'setup',
#   'pattern'],
#  ['be',
#   'go',
#   'to',
#   'make',
#   'big',
#   'move',
#   'higher',
#   'also',
#   'watch',
#   'apple',
#   'think',
#   'they',
#   'short',
#   'the',
#   'put',
#   'spread',
#   'for',
#   'july'],
#  ['weekly',
#   'recap',
#   'price',
#   'move',
#   'since',
#   'post',
#   'expect',
#   'consolidation',
#   'other',
#   'trade',
#   'include',
#   'akam',
#   'len',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx'],
#  ['it',
#   'good',
#   'that',
#   'even',
#   'bull',
#   'be',
#   'cautious',
#   'stun',
#   'bearish',
#   'deeply',
#   'disappoint',
#   'too',
#   'bad',
#   'continue',
#   'it',
#   'old',
#   'ways',
#   'hopefully',
#   'we',
#   'be',
#   'close'],
#  ['weekly',
#   'recap',
#   'price',
#   'move',
#   'since',
#   'post',
#   'support',
#   'other',
#   'trade',
#   'include',
#   'len',
#   'hsy',
#   'uri',
#   'sonc',
#   'dri',
#   'kmx',
#   'wynn'],
#  ['end', 'june', 'kill', 'it', 'best', 'month', 'since', 'february'],
#  ['funny',
#   'how',
#   'long',
#   'the',
#   'same',
#   'thing',
#   'have',
#   'be',
#   'go',
#   'on',
#   'with',
#   'this',
#   'about',
#   'years',
#   'of',
#   'this',
#   'similar',
#   'story',
#   'different',
#   'day'],
#  ['bearish',
#   'crab',
#   'well',
#   'measure',
#   'bearish',
#   'crab',
#   'with',
#   'bearish',
#   'divergence',
#   'you',
#   'can',
#   'really',
#   'see',
#   'the',
#   'momentum',
#   'start',
#   'to',
#   'shi'],
#  ['staanalystalert',
#   'for',
#   'jefferies',
#   'maintain',
#   'with',
#   'rat',
#   'of',
#   'buy',
#   'set',
#   'target',
#   'price',
#   'at',
#   'usd',
#   'our',
#   'own',
#   'verdict',
#   'be',
#   'buy'],
#  ['google', 'venture', 'company'],
#  ['tariff',
#   'increase',
#   'profit',
#   'how',
#   'can',
#   'it',
#   'be',
#   'bad',
#   'recession',
#   'if',
#   'it',
#   'come',
#   'be',
#   'years',
#   'down',
#   'the',
#   'line',
#   'keep',
#   'buy',
#   'short',
#   'pure',
#   'bull'],
#  ['beanscreen', 'for'],
#  ['the',
#   'min',
#   'chart',
#   'from',
#   'friday',
#   'indicate',
#   'some',
#   'nice',
#   'accumulation',
#   'at',
#   'eod',
#   'could',
#   'be',
#   'nice',
#   'pop',
#   'monday'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'at', 'be'],
#  ['weekly',
#   'recap',
#   'price',
#   'move',
#   'since',
#   'post',
#   'heavy',
#   'resistance',
#   'at',
#   'other',
#   'trade',
#   'include',
#   'apog',
#   'acn',
#   'camp',
#   'gi',
#   'payx',
#   'fdx',
#   'goos'],
#  ['can', 'we', 'squeeze', 'the', 'short'],
#  ['weekly',
#   'recap',
#   'price',
#   'move',
#   'since',
#   'post',
#   'pullback',
#   'to',
#   'before',
#   'more',
#   'upside',
#   'other',
#   'trade',
#   'include',
#   'camp',
#   'gi',
#   'payx',
#   'fdx',
#   'goos',
#   'nvda',
#   'apog'],
#  ['still', 'hold', 'call', 'for', 'next', 'week'],
#  ['be', 'safe', 'but', 'their', 'buyback', 'yield', 'be', 'div', 'yield'],
#  ['add',
#   'at',
#   'gladly',
#   'let',
#   'irrationality',
#   'reign',
#   'as',
#   'long',
#   'as',
#   'possible',
#   'excess',
#   'gain',
#   'be',
#   'welcome',
#   'gl'],
#  ['look',
#   'at',
#   'friday',
#   'data',
#   'see',
#   'different',
#   'stories',
#   'on',
#   'the',
#   'chart',
#   'take',
#   'look',
#   'and',
#   'tell',
#   'me',
#   'what',
#   'you',
#   'think'],
#  ['the',
#   'short',
#   'probably',
#   'aren',
#   'jump',
#   'for',
#   'joy',
#   'today',
#   'in',
#   'at',
#   'least',
#   'for',
#   'give',
#   'the',
#   'price',
#   'action'],
#  ['bounce',
#   'off',
#   'support',
#   'need',
#   'continuation',
#   'next',
#   'week',
#   'make',
#   'me',
#   'feel',
#   'more',
#   'hopeful',
#   'for'],
#  ['data',
#   'science',
#   'officially',
#   'become',
#   'major',
#   'in',
#   'universities',
#   'this',
#   'year',
#   'to',
#   'support',
#   'ai',
#   'industry',
#   'these',
#   'be',
#   'no',
#   'brainers',
#   'in',
#   'the',
#   'data',
#   'era'],
#  ['short', 'ratio', 'of', 'be', 'at', 'and', 'short', 'to', 'float', 'be'],
#  [],
#  ['weekly',
#   'recap',
#   'price',
#   'move',
#   'since',
#   'post',
#   'support',
#   'at',
#   'other',
#   'trade',
#   'include',
#   'payx',
#   'fdx',
#   'goos',
#   'nvda',
#   'apog',
#   'acn',
#   'camp'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'on', 'be'],
#  [],
#  ['have',
#   'better',
#   'return',
#   'on',
#   'equity',
#   'than',
#   'the',
#   'industry',
#   'average',
#   'of'],
#  ['second', 'not', 'minutes'],
#  ['weekly',
#   'recap',
#   'price',
#   'move',
#   'since',
#   'post',
#   'rule',
#   'apply',
#   'here',
#   'other',
#   'trade',
#   'include',
#   'zbra',
#   'six',
#   'fc',
#   'gbx',
#   'fds',
#   'avav',
#   'baba'],
#  ['trump',
#   'be',
#   'kill',
#   'the',
#   'tax',
#   'cut',
#   'with',
#   'oil',
#   'price',
#   'and',
#   'tariff',
#   'no',
#   'idea',
#   'what',
#   'he',
#   'do',
#   'right',
#   'now'],
#  ['haven',
#   'post',
#   'on',
#   'stocktwits',
#   'in',
#   'while',
#   'these',
#   'weekly',
#   'chart',
#   'look',
#   'good'],
#  ['today', 'insight', 'on'],
#  ['omg', 'toy', 'story', 'land', 'look', 'amaze'],
#  ['stock',
#   'have',
#   'contribute',
#   'of',
#   'ytd',
#   'return',
#   'what',
#   'do',
#   'you',
#   'own'],
#  ['today', 'insight', 'on'],
#  ['my', 'rd', 'most', 'popular', 'word'],
#  ['trump',
#   'tweet',
#   'and',
#   'then',
#   'he',
#   'may',
#   'be',
#   'buyin',
#   'those',
#   'dip',
#   'haha',
#   'still',
#   'makin',
#   'it',
#   'rain',
#   'up',
#   'in',
#   'the',
#   'white',
#   'house'],
#  ['have',
#   'poor',
#   'technical',
#   'rat',
#   'and',
#   'the',
#   'quality',
#   'of',
#   'the',
#   'setup',
#   'be',
#   'also',
#   'not',
#   'perfect',
#   'at',
#   'the',
#   'moment'],
#  ['doubt',
#   'it',
#   'go',
#   'down',
#   'monday',
#   'and',
#   'doubt',
#   'saudi',
#   'arabia',
#   'increase',
#   'production'],
#  ['measure',
#   'over',
#   'the',
#   'past',
#   'years',
#   'show',
#   'very',
#   'strong',
#   'growth',
#   'in',
#   'eps'],
#  ['constellation', 'brand'],
#  ['the',
#   'short',
#   'probably',
#   'aren',
#   'jump',
#   'for',
#   'joy',
#   'today',
#   'in',
#   'at',
#   'least',
#   'for',
#   'give',
#   'the',
#   'price',
#   'action'],
#  ['here'],
#  ['do', 'disney', 'just', 'clinch', 'the', 'deal', 'to', 'acquire', 'fox'],
#  ['new', 'ways', 'match', 'group', 'can', 'counter', 'facebook'],
#  ['aggregate', 'short', 'volume', 'report', 'to', 'finra', 'for', 'be', 'on'],
#  ['southwest',
#   'airlines',
#   'be',
#   'add',
#   'flight',
#   'in',
#   'dallas',
#   'as',
#   'delta',
#   'spat',
#   'continue'],
#  ['what', 'california'],
#  ['better', 'buy', 'netflix', 'inc', 'nflx', 'versus', 'facebook', 'fb'],
#  ['one', 'thing', 'that', 'starbucks', 'be', 'do', 'wrong'],
#  [],
#  ['use',
#   'iex',
#   'data',
#   'we',
#   'calculate',
#   'that',
#   'shorters',
#   'have',
#   'lose',
#   'in',
#   'on'],
#  ['bull',
#   'list',
#   'after',
#   'their',
#   'emergence',
#   'from',
#   'bankruptcy',
#   'emergency'],
#  ['zwj',
#   'investment',
#   'counsel',
#   'inc',
#   'lower',
#   'stake',
#   'in',
#   'unitedhealth',
#   'group',
#   'inc',
#   'unh'],
#  ['list', 'of', 'tyzen', 'and', 'vega', 'laptops', 'as', 'of', 'june', 'th'],
#  ['invest',
#   'in',
#   'the',
#   'company',
#   'like',
#   'an',
#   'annuity',
#   'or',
#   'yr',
#   'bond',
#   'continue',
#   'to',
#   'add',
#   'share',
#   'unsure',
#   'if',
#   'the',
#   'country',
#   'be',
#   'grow',
#   'amd',
#   'be'],
#  ['list', 'of', 'ryzen', 'and', 'vega', 'laptops', 'as', 'of'],
#  ['gettin', 'blast'],
#  ['weekly',
#   'recap',
#   'price',
#   'move',
#   'since',
#   'post',
#   'strong',
#   'support',
#   'at',
#   'current',
#   'price',
#   'other',
#   'trade',
#   'include',
#   'cgnx',
#   'cx',
#   'aaoi',
#   'aa',
#   'amswa',
#   'yy',
#   'snx'],
#  ['bearish',
#   'shark',
#   'bearish',
#   'shark',
#   'with',
#   'bearish',
#   'divergence',
#   'be',
#   'definitely',
#   'jump',
#   'into',
#   'the',
#   'august',
#   'put',
#   'on',
#   'monday'],
#  ['so',
#   'be',
#   'gs',
#   'go',
#   'to',
#   'give',
#   'us',
#   'price',
#   'point',
#   'before',
#   'or',
#   'after',
#   'earn'],
#  ['the',
#   'short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'be'],
#  ['huge', 'volume', 'at', 'close', 'on', 'friday'],
#  ['look', 'for', 'scalp'],
#  ['this',
#   'be',
#   'one',
#   'giant',
#   'ferment',
#   'turd',
#   'of',
#   'stock',
#   'when',
#   'will',
#   'it',
#   'go',
#   'back',
#   'up',
#   'to'],
#  ['buffet', 'and', 'be', 'buy', 'at', 'per', 'share'],
#  ['in', 'put', 'from', 'last', 'week', 'target', 'zone', 'mark'],
#  ['option',
#   'volume',
#   'be',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'be',
#   'and',
#   'put',
#   'volume',
#   'be'],
#  ['compare',
#   'to',
#   'an',
#   'average',
#   'industry',
#   'price',
#   'book',
#   'ratio',
#   'of',
#   'be',
#   'value',
#   'rather',
#   'cheaply'],
#  ['the',
#   'eps',
#   'have',
#   'be',
#   'grow',
#   'by',
#   'on',
#   'average',
#   'over',
#   'the',
#   'past',
#   'years',
#   'this',
#   'be',
#   'quite',
#   'good'],
#  ['mitch',
#   'do',
#   'great',
#   'job',
#   'of',
#   'get',
#   'netflix',
#   'start',
#   'he',
#   'clearly',
#   'know',
#   'how',
#   'to',
#   'make',
#   'big',
#   'things',
#   'happen',
#   'in',
#   'this',
#   'industry'],
#  ['cup',
#   'and',
#   'holder',
#   'inverse',
#   'bearish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['with',
#   'debt',
#   'to',
#   'equity',
#   'ratio',
#   'of',
#   'be',
#   'do',
#   'better',
#   'than',
#   'the',
#   'average',
#   'in',
#   'the',
#   'industry'],
#  ['sell',
#   'in',
#   'may',
#   'amp',
#   'go',
#   'away',
#   'have',
#   'be',
#   'pattern',
#   'for',
#   'years',
#   'interest',
#   'to',
#   'see',
#   'so',
#   'much',
#   'trade',
#   'in',
#   'this',
#   'time',
#   'frame',
#   'bank',
#   'love',
#   'you',
#   'traders'],
#  ['meanwhile', 'in', 'galaxy', 'far', 'far', 'away'],
#  ['broaden',
#   'wedge',
#   'descend',
#   'bearish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['happy', 'trade', 'guy', 'look', 'to', 'exit', 'today'],
#  ['large', 'put', 'spread', 'in', 'open', 'interest', 'im', 'bearish'],
#  [],
#  ['pt'],
#  ['three',
#   'fall',
#   'peak',
#   'bearish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['happy',
#   'fourth',
#   'everyone',
#   'have',
#   'coke',
#   'and',
#   'smile',
#   'thank',
#   'for',
#   'the',
#   'dividend',
#   'and'],
#  [],
#  ['sell', 'will', 'prove', 'to', 'be', 'terrible', 'error'],
#  ['the',
#   'end',
#   'of',
#   'the',
#   'article',
#   'just',
#   'post',
#   'hint',
#   'at',
#   'possible',
#   'acquisition',
#   'of',
#   'sogou',
#   'finger',
#   'cross'],
#  ['triple',
#   'top',
#   'bearish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'on', 'be'],
#  ['bro',
#   'that',
#   'not',
#   'how',
#   'it',
#   'work',
#   'delete',
#   'the',
#   'blue',
#   'arrow',
#   'that',
#   'your',
#   'delusion'],
#  ['let',
#   'me',
#   'guess',
#   'everyone',
#   'be',
#   'still',
#   'bullish',
#   'here',
#   'even',
#   'after',
#   'it',
#   'close',
#   'under',
#   'the',
#   'ma',
#   'on',
#   'the',
#   'daily',
#   'overbought',
#   'level',
#   'trend',
#   'be',
#   'change'],
#  ['cup',
#   'and',
#   'holder',
#   'bullish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['mr', 'hold', 'yo'],
#  ['option',
#   'volume',
#   'be',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'be',
#   'and',
#   'put',
#   'volume',
#   'be'],
#  ['hi',
#   'everyone',
#   'go',
#   'to',
#   'bed',
#   'good',
#   'night',
#   'everyone',
#   'happy',
#   'money',
#   'monday',
#   'soon',
#   'be',
#   'prepare'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'be'],
#  ['amazon',
#   'new',
#   'warehouse',
#   'policy',
#   'will',
#   'start',
#   'penalize',
#   'sellers',
#   'that',
#   'store',
#   'products',
#   'for',
#   'too',
#   'long'],
#  ['just',
#   'fyi',
#   'trump',
#   'era',
#   'ramp',
#   'up',
#   'tech',
#   'worker',
#   'revolt',
#   'the',
#   'hill'],
#  ['this',
#   'company',
#   'go',
#   'off',
#   'the',
#   'rail',
#   'the',
#   'people',
#   'that',
#   'work',
#   'there',
#   'and',
#   'the',
#   'store',
#   'managers',
#   'say',
#   'it',
#   'all',
#   'circuit',
#   'city',
#   'deux'],
#  ['why',
#   'do',
#   'bank',
#   'fail',
#   'to',
#   'rally',
#   'despite',
#   'huge',
#   'bb',
#   'and',
#   'div',
#   'incr',
#   'me',
#   'think',
#   'mm',
#   'drive',
#   'down',
#   'price',
#   'to',
#   'get',
#   'in',
#   'on',
#   'the',
#   'cheap',
#   'prior',
#   'the',
#   'rally'],
#  ['bear',
#   'use',
#   'all',
#   'arguments',
#   'sound',
#   'like',
#   'short',
#   'position',
#   'be',
#   'become',
#   'lose',
#   'this',
#   'week'],
#  ['gameranx', 'popular', 'youtube', 'game', 'channel'],
#  ['facebook', 'the', 'cash', 'machine'],
#  ['and',
#   'it',
#   'will',
#   'take',
#   'all',
#   'semi',
#   'up',
#   'more',
#   'week',
#   'and',
#   'then',
#   'uptrend',
#   'continue'],
#  ['cheap',
#   'dividend',
#   'champion',
#   'with',
#   'low',
#   'forward',
#   'altria',
#   'aflac',
#   'eatonvance'],
#  ['look',
#   'at',
#   'the',
#   'graph',
#   'tripple',
#   'bottom',
#   'reach',
#   'for',
#   'head',
#   'to',
#   'and',
#   'to',
#   'in',
#   'to',
#   'weeks'],
#  ['if',
#   'you',
#   'have',
#   'penis',
#   'and',
#   'want',
#   'vagina',
#   'like',
#   'alteration',
#   'go',
#   'get',
#   'job',
#   'at',
#   'sbux'],
#  ['oled',
#   'panel',
#   'post',
#   'steady',
#   'growth',
#   'amid',
#   'weak',
#   'demand',
#   'in',
#   'display',
#   'market',
#   'data'],
#  ['facebook', 'the', 'cash', 'machine'],
#  [],
#  ['option',
#   'volume',
#   'be',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'be',
#   'and',
#   'put',
#   'volume',
#   'be'],
#  ['microsoft',
#   'andromeda',
#   'leak',
#   'foldable',
#   'dual',
#   'screen',
#   'surface',
#   'device',
#   'that',
#   'fit',
#   'in',
#   'your',
#   'pocket'],
#  ['the',
#   'short',
#   'sale',
#   'volume',
#   'not',
#   'short',
#   'interest',
#   'for',
#   'on',
#   'be'],
#  ['have',
#   'good',
#   'piotroski',
#   'score',
#   'of',
#   'this',
#   'indicate',
#   'good',
#   'health',
#   'and',
#   'profitability'],
#  ['short',
#   'interest',
#   'ratio',
#   'of',
#   'be',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'be'],
#  ['my',
#   'original',
#   'thesis',
#   'be',
#   'predicate',
#   'on',
#   'amd',
#   'have',
#   'competitive',
#   'server',
#   'product',
#   'around',
#   'this',
#   'time',
#   'didn',
#   'think',
#   'intel',
#   'would',
#   'shit',
#   'the',
#   'bed'],
#  ['bullish', 'bat', 'bullish', 'bat', 'with', 'bullish', 'divergence'],
#  ['epyc',
#   'server',
#   'adoption',
#   'will',
#   'snow',
#   'ball',
#   'this',
#   'year',
#   'intel',
#   'security',
#   'flaw',
#   'nm',
#   'fail',
#   'fire',
#   'ceo',
#   'you',
#   'can',
#   'make',
#   'this',
#   'sh',
#   'up'],
#  ['my',
#   'original',
#   'thesis',
#   'be',
#   'predicate',
#   'on',
#   'amd',
#   'have',
#   'competitive',
#   'server',
#   'product',
#   'around',
#   'this',
#   'time',
#   'didn',
#   'think',
#   'intel',
#   'would',
#   'sh',
#   'the',
#   'bed'],
#  ['think', 'will', 'buy', 'as', 'many', 'as', 'can', 'under'],
#  ['new', 'ways', 'match', 'group', 'can', 'counter', 'facebook'],
#  ['wowza',
#   'for',
#   'if',
#   'start',
#   'one',
#   'month',
#   'ago',
#   'the',
#   'short',
#   'return',
#   'would',
#   'be',
#   'around',
#   'as',
#   'of',
#   'iex',
#   'data'],
#  ['be',
#   'the',
#   'real',
#   'boom',
#   'in',
#   'the',
#   'social',
#   'media',
#   'and',
#   'it',
#   'will',
#   'get',
#   'much',
#   'bigger',
#   'it',
#   'will',
#   'be',
#   'in',
#   'before',
#   'christmas'],
#  ['the',
#   'current',
#   'ratio',
#   'of',
#   'be',
#   'much',
#   'better',
#   'than',
#   'the',
#   'industry',
#   'average',
#   'of'],
#  ['celgene',
#   'investors',
#   'breathe',
#   'sigh',
#   'of',
#   'relief',
#   'after',
#   'acceleron',
#   'success'],
#  ['bear',
#   'and',
#   'shorties',
#   'make',
#   'huge',
#   'mistake',
#   'and',
#   'they',
#   'don',
#   'have',
#   'the',
#   'money',
#   'to',
#   'buy',
#   'back',
#   'when',
#   'short',
#   'it',
#   'at',
#   'so',
#   'they',
#   'cry',
#   'out',
#   'here',
#   'everyday'],
#  ['today', 'insight', 'on'],
#  ['the',
#   'industry',
#   'average',
#   'roa',
#   'be',
#   'outperform',
#   'of',
#   'its',
#   'industry',
#   'peer'],
#  ['encourage',
#   'you',
#   'to',
#   'no',
#   'longer',
#   'be',
#   'sheep',
#   'end',
#   'your',
#   'racist',
#   'and',
#   'hateful',
#   'ways',
#   'buy',
#   'amd',
#   'and',
#   'walk',
#   'away',
#   'from',
#   'the',
#   'democratic',
#   'party',
#   'walkaway'],
#  ['it',
#   'happen',
#   'look',
#   'to',
#   'ease',
#   'the',
#   'flatten',
#   'of',
#   'the',
#   'yc',
#   'start',
#   'this',
#   'week',
#   'lot',
#   'of',
#   'traders',
#   'def',
#   'offsides',
#   'now'],
#  ['daily', 'or', 'weekly', 'chart', 'all', 'look', 'horrible'],
#  ['if', 'spotify', 'add', 'more', 'video', 'content', 'look', 'out'],
#  ['market',
#   'position',
#   'be',
#   'very',
#   'underweight',
#   'crowdthnk',
#   'algo',
#   'forecast',
#   'chance',
#   'move',
#   'lower'],
#  ['add',
#   'more',
#   'at',
#   'this',
#   'no',
#   'brainer',
#   'if',
#   'you',
#   're',
#   'long',
#   'there',
#   'be',
#   'no',
#   'peer',
#   'and',
#   'they',
#   'be',
#   'top',
#   'dog',
#   'amd',
#   'and',
#   'mu',
#   'notwithstanding'],
#  ['bearish',
#   'bat',
#   'bearish',
#   'bat',
#   'with',
#   'some',
#   'serious',
#   'bearish',
#   'divergence',
#   'something',
#   'be',
#   'about',
#   'to',
#   'give'],
#  ['have',
#   'be',
#   'proposition',
#   'in',
#   'july',
#   'since',
#   'with',
#   'net',
#   'return',
#   'of'],
#  ['in',
#   'term',
#   'of',
#   'negative',
#   'for',
#   'there',
#   'be',
#   'bearish',
#   'indicators',
#   'as',
#   'of'],
#  ['quite', 'over', 'value', 'in', 'my', 'opinion'],
#  ['brexit',
#   'bankers',
#   'risk',
#   'life',
#   'on',
#   'the',
#   'edge',
#   'as',
#   'luxembourg',
#   'fill',
#   'up',
#   'via'],
#  ['market', 'history'],
#  ['so', 'amd', 'be', 'use', 'liquid', 'inside', 'of', 'the', 'gpu'],
#  ['curve',
#   'flatten',
#   'juggernaut',
#   'face',
#   'risk',
#   'from',
#   'feed',
#   'concern',
#   'on',
#   'trade',
#   'via'],
#  ['as',
#   'it',
#   'pertain',
#   'to',
#   'if',
#   'start',
#   'days',
#   'ago',
#   'bearish',
#   'investors',
#   'would',
#   'have',
#   'lose',
#   'around',
#   'as',
#   'of',
#   'accord',
#   'to',
#   'iex'],
#  [],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'on', 'be'],
#  ['study',
#   'of',
#   'watchlist',
#   'trade',
#   'wisely',
#   'invest',
#   'wisely',
#   'read',
#   'the',
#   'wallstreet',
#   'runners'],
#  ['wait', 'for', 'the', 'pull', 'back', 'slow', 'steady', 'stock'],
#  ['think',
#   'friday',
#   'flush',
#   'be',
#   'for',
#   'cheap',
#   'share',
#   'just',
#   'like',
#   'they',
#   'do',
#   'in',
#   'oil',
#   'before',
#   'the',
#   'opec',
#   'meet'],
#  ['china', 'attack'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'be'],
#  ['be',
#   'rat',
#   'sell',
#   'since',
#   'june',
#   'and',
#   'be',
#   'below',
#   'its',
#   'median',
#   'level'],
#  ['dont', 'trust', 'this', 'company'],
#  ['today', 'insight', 'on'],
#  ['the',
#   'anticipation',
#   'be',
#   'rise',
#   'which',
#   'analyst',
#   'be',
#   'right',
#   'june'],
#  ['sorry',
#   'itsallaboutheoptions',
#   'stock',
#   'price',
#   'be',
#   'not',
#   'so',
#   'we',
#   'be',
#   'higher',
#   'than',
#   'you',
#   'predict',
#   'not',
#   'lower'],
#  ['warren', 'diggered', 'as', 'they', 'exit'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'at', 'be'],
#  ['another', 'analyst', 'opinion', 'on', 'june'],
#  [],
#  ['and',
#   'be',
#   'all',
#   'down',
#   'because',
#   'of',
#   'trade',
#   'concern',
#   'will',
#   'still',
#   'be',
#   'worth',
#   'its',
#   'weight',
#   'in',
#   'faucets',
#   'and',
#   'now',
#   'little',
#   'bite',
#   'of',
#   'light'],
#  ['three',
#   'fall',
#   'peak',
#   'bearish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'be'],
#  ['rectangle',
#   'top',
#   'bullish',
#   'with',
#   'confidence',
#   'to',
#   'reach',
#   'target',
#   'price',
#   'usd'],
#  ['any', 'more', 'really', 'jetsonbs', 'design', 'they', 'announce'],
#  ['bull', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['cogsworth', 'cog', 'will', 'take', 'on', 'boeing', 'soon', 'right'],
#  ['really',
#   'bake',
#   'right',
#   'now',
#   'have',
#   'deep',
#   'thoughts',
#   'short',
#   'come',
#   'back',
#   'to',
#   'look',
#   'at',
#   'this',
#   'tweet',
#   'in',
#   'years'],
#  ['this',
#   'one',
#   'will',
#   'test',
#   'if',
#   'fail',
#   'my',
#   'target',
#   'be',
#   'to',
#   'start',
#   'buy',
#   'this',
#   'again',
#   'houseofpain'],
#  [],
#  ['make', 'more', 'than', 'ever', 'thank', 'to', 'amp'],
#  [],
#  ['atl', 'feed', 'forecast', 'whew', 'baby', 'up', 'we', 'go'],
#  ['here',
#   'it',
#   'be',
#   'june',
#   'grr',
#   'date',
#   'be',
#   'come',
#   'out',
#   'early',
#   'read',
#   'away'],
#  ['bull', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['stericycle',
#   'current',
#   'chance',
#   'of',
#   'distress',
#   'be',
#   'about',
#   'below',
#   'average'],
#  ['ggr', 'be', 'out', 'for', 'june'],
#  ['today', 'insight', 'on'],
#  ['fyi'],
#  ['will', 'this', 'go', 'over', 'before', 'earn'],
#  ['extremely',
#   'undervalue',
#   'this',
#   'will',
#   'be',
#   'within',
#   'year',
#   'great',
#   'for',
#   'midterm',
#   'investment'],
#  ['may',
#   'go',
#   'slightly',
#   'down',
#   'on',
#   'this',
#   'news',
#   'june',
#   'ggr',
#   'itsallaboutheoptions'],
#  ['stupid', 'spammers', 'waste', 'time'],
#  ['but',
#   'it',
#   'already',
#   'oversold',
#   'so',
#   'not',
#   'much',
#   'consolidation',
#   'and',
#   'then',
#   'up'],
#  ['this', 'be', 'just', 'the', 'start'],
#  ['short',
#   'interest',
#   'ratio',
#   'of',
#   'be',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'be'],
#  ['purchase',
#   'pill',
#   'pack',
#   'last',
#   'thursday',
#   'and',
#   'break',
#   'into',
#   'the',
#   'pharmaceutical',
#   'field',
#   'increase',
#   'amazon',
#   'bottom',
#   'line',
#   'will',
#   'retest',
#   'quickly'],
#  ['june',
#   'ggr',
#   'up',
#   'still',
#   'after',
#   'the',
#   'soccer',
#   'world',
#   'cup',
#   'and',
#   'holiday'],
#  ['purchase',
#   'pill',
#   'pack',
#   'last',
#   'thurs',
#   'amp',
#   'break',
#   'into',
#   'the',
#   'pharmaceutical',
#   'field',
#   'increase',
#   'amazon',
#   'bottom',
#   'line',
#   'will',
#   'retest',
#   'quickly'],
#  ['buy', 'back', 'they', 'want', 'cheap'],
#  ['not',
#   'too',
#   'expensive',
#   'and',
#   'grow',
#   'strongly',
#   'check',
#   'out',
#   'now',
#   'part',
#   'of',
#   'our',
#   'affordable',
#   'growth',
#   'selection'],
#  ['option',
#   'volume',
#   'be',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'be',
#   'and',
#   'put',
#   'volume',
#   'be'],
#  ['the',
#   'long',
#   'term',
#   'trend',
#   'be',
#   'positive',
#   'and',
#   'the',
#   'short',
#   'term',
#   'trend',
#   'be',
#   'neutral',
#   'so',
#   'the',
#   'benefit',
#   'of',
#   'the',
#   'doubt',
#   'for',
#   'now'],
#  ['lot',
#   'of',
#   'buyers',
#   'fri',
#   'when',
#   'mm',
#   'pin',
#   'at',
#   'quot',
#   'traders',
#   'buy',
#   'amazon',
#   'com',
#   'amzn',
#   'on',
#   'weakness',
#   'quot'],
#  ['in',
#   'term',
#   'of',
#   'positives',
#   'for',
#   'there',
#   'be',
#   'bullish',
#   'indicators',
#   'as',
#   'of'],
#  ['know', 'what', 'hold'],
#  ['never',
#   'have',
#   'see',
#   'right',
#   'angle',
#   'in',
#   'apple',
#   'lol',
#   'that',
#   'be',
#   'crazy'],
#  ['wan',
#   'na',
#   'hear',
#   'the',
#   'er',
#   'ok',
#   'yeah',
#   'all',
#   'get',
#   'great',
#   'products',
#   'so',
#   'what',
#   'this',
#   'be',
#   'the',
#   'stock',
#   'market',
#   'want',
#   'report',
#   'what',
#   'the',
#   'news'],
#  ['starbucks',
#   'to',
#   'become',
#   'the',
#   'pioneer',
#   'in',
#   'medical',
#   'coverage',
#   'for',
#   'sex',
#   'change',
#   'get',
#   'your',
#   'free',
#   'sex',
#   'change',
#   'here'],
#  ['today', 'insight', 'on'],
#  ['today', 'insight', 'on'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'on', 'be'],
#  ['all',
#   'in',
#   'on',
#   'august',
#   'call',
#   'either',
#   'gon',
#   'na',
#   'make',
#   'fortune',
#   'or',
#   'declare',
#   'bankruptcy'],
#  ['wtf'],
#  [],
#  ['macau', 'casino', 'ggr', 'up', 'nearly', 'pct', 'in', 'june', 'govt'],
#  ['jul',
#   'casino',
#   'gross',
#   'game',
#   'revenue',
#   'ggr',
#   'in',
#   'macau',
#   'rise',
#   'by',
#   'percent',
#   'year',
#   'on',
#   'year',
#   'in',
#   'june',
#   'to'],
#  ['what'],
#  ['be', 'gon', 'na', 'be', 'cheaper', 'than', 'also'],
#  ['the',
#   'monster',
#   'core',
#   'amd',
#   'ryzen',
#   'threadripper',
#   'cpu',
#   'rumor',
#   'usd'],
#  ['we',
#   'have',
#   'detect',
#   'negative',
#   'indicators',
#   'as',
#   'of',
#   'for',
#   'more',
#   'info',
#   'at'],
#  ['someone', 'give', 'me', 'like'],
#  ['short',
#   'interest',
#   'ratio',
#   'be',
#   'on',
#   'and',
#   'short',
#   'to',
#   'float',
#   'be'],
#  [],
#  ['value', 'll', 'take', 'at', 'this', 'point'],
#  [],
#  ['short',
#   'interest',
#   'ratio',
#   'of',
#   'be',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'be'],
#  ['trump', 'will', 'cause', 'oil', 'price', 'to', 'go', 'down'],
#  ['if',
#   'be',
#   'and',
#   'need',
#   'to',
#   'buyback',
#   'bln',
#   'share',
#   'wouldn',
#   'try',
#   'to',
#   'buy',
#   'the',
#   'dip'],
#  ['option',
#   'volume',
#   'be',
#   'normal',
#   'on',
#   'friday',
#   'with',
#   'contract',
#   'call',
#   'volume',
#   'be',
#   'and',
#   'put',
#   'volume',
#   'be'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'be'],
#  ['gigabyte', 'amp', 'epyc', 'cpus', 'with', 'large', 'density', 'servers'],
#  ['now',
#   'intel',
#   'can',
#   'produce',
#   'full',
#   'silicon',
#   'wafers',
#   'for',
#   'quantum',
#   'compute',
#   'chip'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'on', 'be'],
#  ['good',
#   'technicals',
#   'but',
#   'also',
#   'nice',
#   'setup',
#   'pattern',
#   'form',
#   'for',
#   'now',
#   'part',
#   'of',
#   'our',
#   'top',
#   'breakout',
#   'selection'],
#  ['bear', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['june',
#   'ggr',
#   'only',
#   'up',
#   'very',
#   'bad',
#   'stock',
#   'be',
#   'go',
#   'to',
#   'get',
#   'crush'],
#  ['amazon',
#   'with',
#   'hook',
#   'pattern',
#   'set',
#   'up',
#   'on',
#   'the',
#   'monthly',
#   'look',
#   'at',
#   'strong',
#   'move',
#   'up',
#   'on',
#   'monday',
#   'expect'],
#  ['paychex',
#   'social',
#   'hype',
#   'low',
#   'key',
#   'current',
#   'chance',
#   'of',
#   'financial',
#   'distress',
#   'be',
#   'under'],
#  ['today', 'insight', 'on'],
#  [],
#  ['bear', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['buy', 'more', 'on', 'the', 'dip', 'buy', 'opp'],
#  ['here',
#   'be',
#   'an',
#   'example',
#   'of',
#   'hook',
#   'pattern',
#   'virtually',
#   'identical',
#   'to',
#   'what',
#   'amazons',
#   'monthly',
#   'chart',
#   'look',
#   'like',
#   'now'],
#  ['the',
#   'eps',
#   'have',
#   'be',
#   'grow',
#   'by',
#   'on',
#   'average',
#   'over',
#   'the',
#   'past',
#   'years',
#   'this',
#   'be',
#   'quite',
#   'good'],
#  ['short',
#   'interest',
#   'ratio',
#   'of',
#   'be',
#   'at',
#   'and',
#   'short',
#   'to',
#   'float',
#   'be'],
#  ['show', 'up', 'in', 'our', 'top', 'breakout', 'selection'],
#  ['overbought', 'sell', 'signal'],
#  ['short', 'ratio', 'be', 'at', 'and', 'short', 'to', 'float', 'be'],
#  ['rsi', 'deathcross'],
#  ['will',
#   'be',
#   'sell',
#   'pre',
#   'market',
#   'and',
#   'try',
#   'to',
#   'buy',
#   'in',
#   'very',
#   'bullish',
#   'but',
#   'would',
#   'like',
#   'to',
#   'take',
#   'advantage',
#   'of',
#   'dip'],
#  ['as',
#   'it',
#   'pertain',
#   'to',
#   'if',
#   'start',
#   'days',
#   'ago',
#   'bearish',
#   'investors',
#   'would',
#   'have',
#   'lose',
#   'around',
#   'as',
#   'of',
#   'accord',
#   'to',
#   'iex'],
#  ['short',
#   'volume',
#   'for',
#   'on',
#   'be',
#   'th',
#   'percentile',
#   'in',
#   'term',
#   'of',
#   'last',
#   'trade',
#   'days'],
#  ['bring',
#   'on',
#   'the',
#   'gloom',
#   'amp',
#   'doom',
#   'on',
#   'the',
#   'pull',
#   'back',
#   'ahead',
#   'of',
#   'er',
#   'happen',
#   'ever',
#   'time',
#   'after',
#   'don',
#   'fight',
#   'the',
#   'plan',
#   'buy',
#   'it',
#   'no',
#   'way',
#   'it',
#   'fall'],
#  ['overbought', 'death', 'cross', 'sell', 'signal'],
#  ['short',
#   'interest',
#   'ratio',
#   'be',
#   'on',
#   'and',
#   'short',
#   'to',
#   'float',
#   'be'],
#  ['bad',
#   'news',
#   'be',
#   'bake',
#   'in',
#   'to',
#   'the',
#   'sector',
#   'but',
#   'second',
#   'major',
#   'miss',
#   'in',
#   'row',
#   'like',
#   'this',
#   'be',
#   'go',
#   'to',
#   'spook',
#   'lot',
#   'of',
#   'investors'],
#  ['short', 'volume', 'percent', 'for', 'be', 'on', 'versus', 'on'],
#  ['here',
#   'be',
#   'artcile',
#   'with',
#   'expectations',
#   'for',
#   'june',
#   'great',
#   'buy',
#   'opp',
#   'on',
#   'dip',
#   'july',
#   'august'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'be'],
#  ['we',
#   'have',
#   'detect',
#   'positive',
#   'indicators',
#   'as',
#   'of',
#   'for',
#   'more',
#   'info',
#   'at'],
#  ['short', 'ratio', 'be', 'at', 'and', 'short', 'to', 'float', 'be'],
#  ['well',
#   'if',
#   'can',
#   'sell',
#   'premarket',
#   'and',
#   'then',
#   'buy',
#   'back',
#   'in',
#   'summer',
#   'july',
#   'tariff',
#   'come',
#   'up',
#   'lower',
#   'price',
#   'why',
#   'not',
#   'ggr'],
#  ['in',
#   'term',
#   'of',
#   'positives',
#   'for',
#   'there',
#   'be',
#   'bullish',
#   'indicators',
#   'as',
#   'of'],
#  ['be',
#   'currently',
#   'trade',
#   'in',
#   'the',
#   'upper',
#   'part',
#   'of',
#   'its',
#   'week',
#   'range',
#   'outperform',
#   'the',
#   'market'],
#  ['today', 'insight', 'on'],
#  ['huge',
#   'miss',
# ...
#  ['long',
#   'term',
#   'estimate',
#   'per',
#   'barrel',
#   'crude',
#   'could',
#   'be',
#   'in',
#   'the',
#   'card',
#   'rbc',
#   'helima',
#   'croft'],
#  ['the',
#   'long',
#   'and',
#   'short',
#   'term',
#   'trend',
#   'be',
#   'both',
#   'positive',
#   'this',
#   'be',
#   'look',
#   'good'],
#  ['release',
#   'earn',
#   'on',
#   'before',
#   'open',
#   'confirm',
#   'anybody',
#   'buy',
#   'sell',
#   'in',
#   'earn'],
#  ['ba', 'ba'],
#  ['not', 'at', 'all', 'afraid', 'to', 'hold', 'my', 'short', 'in', 'bank'],
#  ['retaliation',
#   'for',
#   'us',
#   'tariff',
#   'on',
#   'sun',
#   'canada',
#   'on',
#   'july',
#   'china',
#   'expect',
#   'to',
#   'impose',
#   'tariff',
#   'on',
#   'us',
#   'soybeans',
#   'cnbc'],
#  ['short', 'ratio', 'of', 'be', 'at', 'and', 'short', 'to', 'float', 'be'],
#  ['wonder', 'how', 'many', 'matebook', 'be', 'sell'],
#  ['bac', 'bac'],
#  ['good', 'plan', 'right', 'here', 'close', 'to', 'mine'],
#  ['very', 'optimistic', 'melikey'],
#  ['high',
#   'oi',
#   'range',
#   'be',
#   'to',
#   'for',
#   'option',
#   'expiration',
#   'maxpain',
#   'options'],
#  ['oversold', 'with', 'sign', 'of', 'possible', 'reversal'],
#  ['would',
#   'not',
#   'want',
#   'to',
#   'be',
#   'in',
#   'this',
#   'for',
#   'the',
#   'next',
#   'er'],
#  ['don', 'tell', 'me', 'you', 'be', 'still', 'hold'],
#  ['ok',
#   'you',
#   'keep',
#   'tell',
#   'tell',
#   'yourself',
#   'that',
#   'he',
#   'bked',
#   'casino',
#   'casino',
#   'now',
#   'and',
#   'soon'],
#  ['this',
#   'be',
#   'the',
#   'only',
#   'table',
#   'service',
#   'can',
#   'afford',
#   'right',
#   'now',
#   'can',
#   'even',
#   'afford',
#   'the',
#   'mcdouble',
#   'anymore',
#   'after',
#   'the',
#   'price',
#   'hike'],
#  ['can',
#   'someone',
#   'explain',
#   'what',
#   'happen',
#   'with',
#   'the',
#   'div',
#   'payout',
#   'if',
#   'buy',
#   'in',
#   'here'],
#  ['economy',
#   'that',
#   'time',
#   'send',
#   'job',
#   'overseas',
#   'after',
#   'support',
#   'them',
#   'gut',
#   'of',
#   'trump',
#   'call',
#   'them',
#   'out'],
#  ['yeah', 'sleep', 'with', 'elon', 'musk'],
#  ['compare',
#   'to',
#   'an',
#   'average',
#   'industry',
#   'price',
#   'book',
#   'ratio',
#   'of',
#   'be',
#   'value',
#   'rather',
#   'cheaply'],
#  ['since',
#   'last',
#   'er',
#   'stock',
#   'drop',
#   'report',
#   'earn',
#   'on',
#   'before',
#   'open',
#   'confirm'],
#  ['if',
#   'all',
#   'be',
#   'nice',
#   'to',
#   'me',
#   'can',
#   'give',
#   'you',
#   'an',
#   'accurate',
#   'direction',
#   'of',
#   'which',
#   'way',
#   'this',
#   'will',
#   'go'],
#  ['below',
#   'all',
#   'sma',
#   'in',
#   'fall',
#   'wedge',
#   'bearish',
#   'until',
#   'breakout'],
#  ['think',
#   'most',
#   'of',
#   'the',
#   'peep',
#   'on',
#   'here',
#   'have',
#   'block',
#   'bro',
#   'time',
#   'to',
#   'use',
#   'an',
#   'alternate',
#   'account',
#   'pastorsdaddy',
#   'sr',
#   'be',
#   'take'],
#  ['you',
#   'bet',
#   'how',
#   'about',
#   'show',
#   'some',
#   'facts',
#   'sport',
#   'now',
#   'have',
#   'control',
#   'of',
#   'nfl',
#   'mlb',
#   'march',
#   'madness',
#   'etc',
#   'roku',
#   'suck',
#   'donkey',
#   'dks'],
#  ['alibaba', 'buy', 'stake', 'in', 'turkey', 'trendyol'],
#  ['think',
#   'the',
#   'whole',
#   'dump',
#   'for',
#   'the',
#   'past',
#   'few',
#   'years',
#   'be',
#   'absolutely',
#   'necessary',
#   'their',
#   'sht',
#   'be',
#   'get',
#   'way',
#   'too',
#   'expensive',
#   'they',
#   'can',
#   'grow',
#   'bter',
#   'now'],
#  ['if', 'feel', 'good', 'to', 'be', 'right', 'with', 'this', 'stock'],
#  ['remember',
#   'even',
#   'the',
#   'capital',
#   'investments',
#   'will',
#   'only',
#   'be',
#   'in',
#   'dividend',
#   'payout'],
#  ['since',
#   'last',
#   'er',
#   'stock',
#   'drop',
#   'report',
#   'earn',
#   'on',
#   'before',
#   'open',
#   'confirm'],
#  ['whats',
#   'up',
#   'bro',
#   'you',
#   'still',
#   'trade',
#   'this',
#   'stock',
#   'or',
#   'do',
#   'you',
#   'give',
#   'up'],
#  ['short', 'volume', 'percent', 'for', 'be', 'on'],
#  ['bull', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['talk',
#   'about',
#   'gravity',
#   'in',
#   'stock',
#   'market',
#   'be',
#   'fool',
#   'errond',
#   'take',
#   'look',
#   'at'],
#  ['read',
#   'your',
#   'comment',
#   'on',
#   'on',
#   'seek',
#   'alpha',
#   'you',
#   'know',
#   'lot',
#   'about',
#   'casino',
#   'stock',
#   'will',
#   'this',
#   'ggr',
#   'hurt',
#   'the',
#   'price',
#   'more',
#   'or',
#   'ok',
#   'here'],
#  ['open', 'tomorrow'],
#  ['be',
#   'more',
#   'then',
#   'enough',
#   'we',
#   'should',
#   'be',
#   'at',
#   'and',
#   'earn',
#   'be',
#   'come',
#   'up'],
#  ['should', 'be', 'load', 'on', 'on', 'this', 'stock', 'here'],
#  ['wall',
#   'street',
#   'be',
#   'full',
#   'of',
#   'idiots',
#   'who',
#   'gamble',
#   'until',
#   'they',
#   'lose'],
#  ['hope',
#   'citibank',
#   'go',
#   'bankrupt',
#   'steal',
#   'money',
#   'by',
#   'nickel',
#   'and',
#   'dim',
#   'costumers',
#   'with',
#   'stupid',
#   'little',
#   'fee'],
#  [],
#  ['don',
#   'worry',
#   'scumbags',
#   'at',
#   'citibank',
#   'll',
#   'make',
#   'more',
#   'money',
#   'short',
#   'your',
#   'stock',
#   'to',
#   'the',
#   'grind',
#   'than',
#   'you',
#   'will',
#   'make',
#   'from',
#   'fee'],
#  ['choppy',
#   'head',
#   'amp',
#   'shoulder',
#   'watch',
#   'for',
#   'the',
#   'breakdown',
#   'watch',
#   'for',
#   'the',
#   'breakdown'],
#  ['release',
#   'earn',
#   'on',
#   'before',
#   'open',
#   'confirm',
#   'anybody',
#   'buy',
#   'sell',
#   'in',
#   'earn'],
#  [],
#  ['it', 'be', 'now', 'time', 'for', 'the', 'trumpy', 'bear', 'market'],
#  ['gravity',
#   'apply',
#   'to',
#   'overbot',
#   'condition',
#   'and',
#   'apply',
#   'to',
#   'in',
#   'past',
#   'as',
#   'well'],
#  ['highlight', 'in', 'cancer', 'from', 'the', 'week'],
#  ['jcp', 'jcpenney', 'have', 'rev', 'per', 'employee', 'of'],
#  ['vrsk',
#   'beta',
#   'of',
#   'veriskanalytics',
#   'be',
#   'make',
#   'it',
#   'less',
#   'volatile',
#   'than',
#   'the',
#   'market'],
#  ['viavisolutions', 'dip', 'by', 'in', 'the', 'last', 'year', 'viav'],
#  ['it', 'gartner', 'have', 'very', 'low', 'roce', 'of'],
#  ['etn', 'the', 'rpe', 'revenue', 'per', 'employee', 'of', 'eatonplc', 'be'],
#  ['rrdonnelleysons',
#   'be',
#   'oversold',
#   'accord',
#   'to',
#   'its',
#   'stoch',
#   'rsi',
#   'of',
#   'rrd'],
#  ['ba', 'the', 'payout', 'ratio', 'of', 'boeing', 'be'],
#  ['release',
#   'earn',
#   'on',
#   'before',
#   'open',
#   'confirm',
#   'anybody',
#   'buy',
#   'sell',
#   'in',
#   'earn'],
#  ['psx', 'fcf', 'of', 'phillips', 'be'],
#  ['citigroup', 'have', 'recommendation', 'mean', 'of'],
#  ['mco',
#   'sma',
#   'of',
#   'moodys',
#   'be',
#   'now',
#   'down',
#   'by',
#   'and',
#   'sma',
#   'be',
#   'now',
#   'up',
#   'by'],
#  ['fslr',
#   'the',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   'of',
#   'firstsolar',
#   'be'],
#  ['aonplc',
#   'have',
#   'beta',
#   'of',
#   'make',
#   'it',
#   'less',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'aon'],
#  ['microsoft', 'have', 'adx', 'of', 'hint', 'its', 'weak', 'trend', 'msft'],
#  ['apa',
#   'apache',
#   'have',
#   'sma',
#   'of',
#   'now',
#   'up',
#   'by',
#   'and',
#   'sma',
#   'of',
#   'now',
#   'up',
#   'by'],
#  ['yte', 'have', 'ppo', 'of', 'incy'],
#  ['jmsmucker', 'have', 'recommendation', 'mean', 'of', 'sjm'],
#  ['tel', 'teconnectivity', 'have', 'ppo', 'of'],
#  ['operate', 'margin', 'of', 'internationalbusinessmachines', 'be', 'ibm'],
#  ['northerntrust', 'have', 'recommendation', 'mean', 'of', 'ntrs'],
#  ['bankofnewyorkmellon', 'have', 'short', 'of', 'float', 'of', 'bk'],
#  ['nowhere',
#   'to',
#   'go',
#   'but',
#   'up',
#   'focus',
#   'on',
#   'fundamentals',
#   'epyc',
#   'vs',
#   'xeon',
#   'tam',
#   'all',
#   'revenue',
#   'and',
#   'profit',
#   'come',
#   'now',
#   'revenue',
#   'ramp',
#   'year',
#   'pt'],
#  ['etfc', 'insider', 'ownership', 'of', 'etrade', 'be'],
#  ['envisionhealthcare', 'have', 'short', 'of', 'float', 'of', 'evhc'],
#  ['baxterinternational',
#   'be',
#   'overbought',
#   'with',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   'of',
#   'bax'],
#  ['profit', 'margin', 'of', 'att', 'be'],
#  ['eogresources',
#   'be',
#   'more',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'with',
#   'beta',
#   'of',
#   'eog'],
#  ['diamondoffshoredrilling',
#   'have',
#   'adx',
#   'of',
#   'signify',
#   'its',
#   'weak',
#   'trend',
#   'do'],
#  ['the', 'dividend', 'yield', 'of', 'averydennison', 'be', 'avy'],
#  ['southern',
#   'have',
#   'very',
#   'high',
#   'return',
#   'on',
#   'capital',
#   'employ',
#   'of',
#   'so'],
#  ['insider', 'ownership', 'of', 'davita', 'be', 'dva'],
#  ['western',
#   'ma',
#   'berkshire',
#   'cty',
#   'today',
#   'already',
#   'deg',
#   'today',
#   'the',
#   'cool',
#   'end',
#   'of',
#   'the',
#   'state'],
#  ['citizens', 'have', 'stoch', 'of', 'make', 'it', 'oversold', 'cfg'],
#  ['bear', 'have', 'lose', 'on', 'alone', 'in', 'accord', 'to', 'iex', 'data'],
#  ['cimarexco', 'have', 'adx', 'of', 'signify', 'its', 'weak', 'trend', 'xec'],
#  ['all', 'allstate', 'have', 'very', 'high', 'return', 'on', 'equity', 'of'],
#  ['cxo', 'conchoresources', 'go', 'up', 'by', 'in', 'the', 'last', 'year'],
#  ['compare',
#   'to',
#   'an',
#   'average',
#   'enterprise',
#   'value',
#   'to',
#   'ebitda',
#   'ratio',
#   'of',
#   'be',
#   'value',
#   'rather',
#   'cheaply'],
#  ['bull', 'have', 'reason', 'on', 'to', 'pay', 'more', 'attention'],
#  ['qepresources',
#   'have',
#   'very',
#   'high',
#   'revenue',
#   'per',
#   'employee',
#   'of',
#   'qep'],
#  ['anss', 'fcf', 'of', 'ansys', 'be'],
#  ['coty', 'the', 'recommendation', 'mean', 'of', 'coty', 'be'],
#  ['mtd', 'profit', 'margin', 'of', 'mettler', 'toledointernational', 'be'],
#  ['anyone', 'know', 'what', 'this', 'be', 'refer', 'to'],
#  ['gross', 'margin', 'of', 'motorolasolutions', 'be', 'msi'],
#  ['operate', 'margin', 'of', 'michaelkors', 'be', 'kors'],
#  ['allegionplc',
#   'be',
#   'overbought',
#   'accord',
#   'to',
#   'its',
#   'stochastic',
#   'rsi',
#   'indicator',
#   'of',
#   'alle'],
#  ['nlsn',
#   'the',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   'of',
#   'nielsennv',
#   'be'],
#  ['wpx', 'wpx', 'have', 'rev', 'per', 'employee', 'of'],
#  ['whr', 'whirlpool', 'have', 'dividend', 'yield', 'of'],
#  ['chrw', 'chrobinsonworldwide', 'have', 'short', 'of', 'float', 'of'],
#  ['the', 'recommendation', 'mean', 'of', 'wellsfargo', 'be', 'wfc'],
#  ['ccl', 'carnival', 'have', 'operate', 'margin', 'of'],
#  ['short', 'sale', 'volume', 'not', 'short', 'interest', 'for', 'on', 'be'],
#  ['sma',
#   'of',
#   'pepsico',
#   'be',
#   'now',
#   'up',
#   'by',
#   'and',
#   'sma',
#   'be',
#   'now',
#   'down',
#   'by',
#   'pep'],
#  ['pfe', 'pfizer', 'have', 'very', 'high', 'return', 'on', 'equity', 'of'],
#  ['so',
#   'funny',
#   'how',
#   'bear',
#   'disappear',
#   'from',
#   'to',
#   'but',
#   'it',
#   'pull',
#   'back',
#   'to',
#   'and',
#   'the',
#   'sky',
#   'be',
#   'fall',
#   'lollll',
#   'the',
#   'nature',
#   'of',
#   'stock',
#   'be',
#   'up',
#   'and',
#   'down'],
#  ['deltaairlines',
#   'have',
#   'adx',
#   'of',
#   'signify',
#   'its',
#   'weak',
#   'trend',
#   'dal'],
#  ['adtalemglobaleducation', 'have', 'operate', 'margin', 'of', 'atge'],
#  ['bsx', 'bostonscientific', 'have', 'institutional', 'ownership', 'of'],
#  ['mck', 'mckesson', 'go', 'down', 'by', 'in', 'the', 'last', 'year'],
#  ['pbct',
#   'peoplesunited',
#   'be',
#   'overbought',
#   'with',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   'of'],
#  ['insider',
#   'ownership',
#   'of',
#   'vertexpharmaceuticalsorporated',
#   'be',
#   'vrtx'],
#  ['bkng', 'volatility', 'of', 'book', 'be'],
#  ['dis', 'waltdisney', 'have', 'ppo', 'of'],
#  ['abbottlaboratories', 'have', 'insider', 'ownership', 'of', 'abt'],
#  ['arthurjgallagherco',
#   'have',
#   'adx',
#   'of',
#   'signify',
#   'its',
#   'strong',
#   'trend',
#   'ajg'],
#  ['disca', 'discoverycommunications', 'have', 'gross', 'margin', 'of'],
#  ['lyondellbasellindustriesnv',
#   'have',
#   'weak',
#   'trend',
#   'accord',
#   'to',
#   'its',
#   'adx',
#   'of',
#   'lyb'],
#  ['so',
#   'basically',
#   'the',
#   'vip',
#   'and',
#   'premium',
#   'mass',
#   'aren',
#   'spend',
#   'as',
#   'much',
#   'analysts',
#   'fool',
#   'by',
#   'the',
#   'appearance',
#   'give',
#   'by',
#   'lower',
#   'quality',
#   'mass'],
#  ['skyworkssolutions', 'have', 'institutional', 'ownership', 'of', 'swks'],
#  ['edisoninternational',
#   'have',
#   'adx',
#   'of',
#   'signify',
#   'its',
#   'weak',
#   'trend',
#   'eix'],
#  ['wmb', 'williamscompanies', 'have', 'volatility', 'of'],
#  ['be',
#   'the',
#   'competition',
#   'profitable',
#   'yes',
#   'be',
#   'they',
#   'collaboration',
#   'with',
#   'waymo',
#   'yes',
#   'do',
#   'they',
#   'have',
#   'cash',
#   'yes'],
#  ['release',
#   'earn',
#   'on',
#   'before',
#   'open',
#   'confirm',
#   'anybody',
#   'buy',
#   'sell',
#   'in',
#   'earn'],
#  ['kroger', 'have', 'very', 'high', 'roce', 'of', 'kr'],
#  ['pcar', 'institutional', 'ownership', 'of', 'paccar', 'be'],
#  ['fcf', 'of', 'citrixsystems', 'be', 'ctxs'],
#  ['profit', 'margin', 'of', 'verisign', 'be', 'vrsn'],
#  ['honeywellinternational',
#   'have',
#   'beta',
#   'of',
#   'make',
#   'it',
#   'more',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'hon'],
#  ['the', 'dividend', 'yield', 'of', 'lincolnnational', 'be', 'lnc'],
#  ['txn',
#   'texasinstrumentsorporated',
#   'have',
#   'very',
#   'high',
#   'return',
#   'on',
#   'equity',
#   'of'],
#  ['tdc', 'short', 'percent', 'of', 'float', 'of', 'teradata', 'be'],
#  ['sma',
#   'of',
#   'smithao',
#   'be',
#   'now',
#   'down',
#   'by',
#   'and',
#   'sma',
#   'be',
#   'now',
#   'down',
#   'by',
#   'aos'],
#  ['idexxlaboratories', 'have', 'operate', 'margin', 'of', 'idxx'],
#  ['bby', 'bestbuyco', 'have', 'revenue', 'per', 'employee', 'of'],
#  ['masco', 'have', 'gross', 'margin', 'of', 'mas'],
#  ['the', 'payout', 'ratio', 'of', 'nike', 'be', 'nke'],
#  ['len', 'lennar', 'rise', 'by', 'in', 'the', 'last', 'months'],
#  ['clf', 'the', 'roce', 'of', 'cliffsnaturalresources', 'be'],
#  ['totalsystemservices',
#   'have',
#   'very',
#   'high',
#   'return',
#   'on',
#   'equity',
#   'of',
#   'tss'],
#  ['symantec', 'dip', 'by', 'in', 'the', 'last', 'year', 'symc'],
#  ['rrc', 'rangeresources', 'go', 'down', 'by', 'in', 'the', 'last', 'months'],
#  ['nsc', 'norfolksouther', 'have', 'revenue', 'per', 'employee', 'of'],
#  ['the',
#   'return',
#   'on',
#   'capital',
#   'employ',
#   'of',
#   'accentureplc',
#   'be',
#   'acn'],
#  ['willistowerswatsonpublic',
#   'be',
#   'less',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'with',
#   'beta',
#   'of',
#   'wltw'],
#  ['genworth', 'have', 'institutional', 'ownership', 'of', 'gnw'],
#  ['martinmariettamaterials',
#   'have',
#   'adx',
#   'of',
#   'signify',
#   'its',
#   'strong',
#   'trend',
#   'mlm'],
#  ['intc', 'operate', 'margin', 'of', 'intel', 'be'],
#  ['operate', 'margin', 'of', 'affiliatedmanagers', 'be', 'amg'],
#  ['spgi', 'spglobal', 'have', 'volatility', 'of'],
#  ['fbhs',
#   'beta',
#   'of',
#   'fortunebrandshomesecurity',
#   'be',
#   'make',
#   'it',
#   'more',
#   'volatile',
#   'than',
#   'the',
#   'market'],
#  ['nwl', 'newellbrands', 'dip', 'by', 'in', 'the', 'last', 'year'],
#  ['coopercompanies', 'have', 'operate', 'margin', 'of', 'coo'],
#  ['brighthouse',
#   'be',
#   'oversold',
#   'accord',
#   'to',
#   'its',
#   'stoch',
#   'rsi',
#   'of',
#   'bhf'],
#  ['ebay', 'the', 'revenue', 'per', 'employee', 'of', 'ebay', 'be'],
#  ['slg', 'operate', 'margin', 'of', 'slgreenrealty', 'be'],
#  ['the', 'recommendation', 'mean', 'of', 'ppgindustries', 'be', 'ppg'],
#  ['tegna', 'dip', 'by', 'in', 'the', 'last', 'months', 'tgna'],
#  ['dollargeneral', 'have', 'gross', 'margin', 'of', 'dg'],
#  ['beta',
#   'of',
#   'hess',
#   'make',
#   'more',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'hes'],
#  ['insider', 'ownership', 'of', 'vulcanmaterials', 'be', 'vmc'],
#  ['jpm', 'of', 'float', 'share', 'of', 'jpmorganchaseco', 'be', 'be', 'short'],
#  ['beta',
#   'of',
#   'perrigo',
#   'be',
#   'make',
#   'it',
#   'less',
#   'volatile',
#   'than',
#   'the',
#   'market',
#   'prgo'],
#  ['mmc',
#   'marshmclennancompanies',
#   'have',
#   'very',
#   'high',
#   'return',
#   'on',
#   'equity',
#   'of'],
#  ['tsn',
#   'tysonfoods',
#   'have',
#   'price',
#   'to',
#   'free',
#   'cash',
#   'flow',
#   'ratio',
#   'of'],
#  ['the',
#   'rpe',
#   'revenue',
#   'per',
#   'employee',
#   'of',
#   'intercontinentalexchange',
#   'be',
#   'ice'],
#  ['bectondickinsonand',
#   'have',
#   'adx',
#   'of',
#   'hint',
#   'its',
#   'weak',
#   'trend',
#   'bdx'],
#  ['the',
#   'percentage',
#   'price',
#   'oscillator',
#   'or',
#   'ppo',
#   'of',
#   'fluor',
#   'be',
#   'flr'],
#  ['pdco',
#   'pattersoncompanies',
#   'have',
#   'price',
#   'to',
#   'free',
#   'cash',
#   'flow',
#   'ratio',
#   'of'],
#  ['footlocker', 'rise', 'by', 'in', 'the', 'last', 'year', 'fl'],
#  ['we',
#   'have',
#   'detect',
#   'negative',
#   'indicators',
#   'as',
#   'of',
#   'for',
#   'more',
#   'info',
#   'at'],
#  ['aph', 'amphenol', 'have', 'fcf', 'of'],
#  ...]

# %%
from collections import Counter


"""
Create a vocabulary by using Bag of words
"""

# TODO: Implement 
c = Counter()
for group in tokenized:
    c.update(group)
bow = c

# %% [markdown]
# ### Frequency of Words Appearing in Message
# With our vocabulary, now we'll remove some of the most common words such as 'the', 'and', 'it', etc. These words don't contribute to identifying sentiment and are really common, resulting in a lot of noise in our input. If we can filter these out, then our network should have an easier time learning.
#
# We also want to remove really rare words that show up in a only a few twits. Here you'll want to divide the count of each word by the number of messages. Then remove words that only appear in some small fraction of the messages.

# %%
{key: value/len(bow) for key, value in bow.items()}
# Out:
# {'great': 0.1820506955563411,
#  'buy': 1.2367282859578714,
#  'at': 1.4369112723794473,
#  'ill': 0.00914932107878813,
#  'wait': 0.19745898400948203,
#  'staanalystalert': 0.042336403900937805,
#  'for': 2.8366950156994033,
#  'jefferies': 0.010979185294545757,
#  'maintain': 0.019192780353912375,
#  'with': 0.7141668919340417,
#  'rat': 0.18447318625106568,
#  'of': 2.192915514337402,
#  'hold': 0.4131542284419122,
#  'set': 0.10004990538770248,
#  'target': 0.17486639911833815,
#  'price': 0.41569108565012164,
#  'usd': 0.03068141648125429,
#  'our': 0.12670769998544426,
#  'own': 0.11374269613857063,
#  'verdict': 0.03883262980599281,
#  'be': 6.026605809818885,
#  'hear': 0.03969557713501487,
#  'there': 0.2623255910669356,
#  'guy': 0.13939198602649144,
#  'who': 0.18340229980661663,
#  'know': 0.23554303299993762,
#  'someone': 0.05354432222245326,
#  'think': 0.33320163856022955,
#  'somebody': 0.011384666569628412,
#  'something': 0.06234014680501549,
#  'on': 2.5097003597346697,
#  'stocktwits': 0.01538749454159822,
#  'reveal': 0.005063317460647522,
#  'yourself': 0.01250753779293423,
#  'why': 0.2247821837765902,
#  'the': 4.138643405210955,
#  'drop': 0.23924434925453827,
#  'warren': 0.0104905283732923,
#  'buffet': 0.013526439458526543,
#  'take': 0.31336424694849346,
#  'out': 0.584329708261421,
#  'his': 0.06502256139402383,
#  'position': 0.18160362645817305,
#  'bear': 0.35088686032729616,
#  'have': 1.1127341914287496,
#  'reason': 0.08168888149549812,
#  'to': 3.936183485475453,
#  'pay': 0.11804703582790958,
#  'more': 0.5743070428978395,
#  'attention': 0.036638872138237924,
#  'ok': 0.047035827909588074,
#  'good': 0.4518413008671061,
#  'we': 0.6711442889521948,
#  're': 0.13139672703832317,
#  'not': 0.7195837058909151,
#  'in': 2.1247634692562016,
#  'over': 0.33925266681915534,
#  'weekend': 0.03696117776714978,
#  'lol': 0.32131791811357635,
#  'daily': 0.1449439604083924,
#  'chart': 0.16806679004387515,
#  'need': 0.23809028716391842,
#  'get': 0.8061695535547192,
#  'back': 0.4521532095402466,
#  'above': 0.1855544696512861,
#  'per': 0.17218398452932981,
#  'week': 0.3845002183360712,
#  'after': 0.3571146368343349,
#  'spike': 0.026356282880372627,
#  'if': 0.6123183131978956,
#  'no': 0.4191116840988958,
#  'news': 0.2035516000914932,
#  'months': 0.07652159447713709,
#  'bo': 0.006362936932066291,
#  'then': 0.21782662036555697,
#  'bingo': 0.0018714520388430267,
#  'what': 0.8221912623983697,
#  'odds': 0.004075606662369258,
#  'strong': 0.1786508910191096,
#  'short': 0.9747250005198478,
#  'ratio': 0.07850741302946497,
#  'and': 2.16456301594893,
#  'float': 0.05003015117173692,
#  'squeeze': 0.06552161527104863,
#  'perfect': 0.020679545029215447,
#  'place': 0.0345594809839679,
#  'an': 0.23298538188018547,
#  'option': 0.08085712503379011,
#  'straddle': 0.02380902871639184,
#  'near': 0.06509534008442328,
#  'support': 0.18035599176561104,
#  'trend': 0.10378241250961719,
#  'start': 0.1785677153729388,
#  'new': 0.4785198893763906,
#  'monday': 0.07554428063463019,
#  'expect': 0.43293963527479157,
#  'volume': 0.4512174835208251,
#  'across': 0.008109625501653115,
#  'key': 0.08803102451602171,
#  'company': 0.2300638373084361,
#  'various': 0.0008733442847934125,
#  'sectors': 0.0023393150485537836,
#  'breakout': 0.06622860826350045,
#  'strategy': 0.015200349337713918,
#  'current': 0.06420120188808717,
#  'portfolio': 0.02443284606267285,
#  'bull': 0.2829115634942089,
#  'catalysts': 0.00349337713917365,
#  'continue': 0.07273710257636563,
#  'this': 2.110852342434135,
#  'uptrend': 0.017550061342039052,
#  'pill': 0.0013412072945041692,
#  'pack': 0.003503774094945,
#  'amazon': 0.11106028154956228,
#  'prime': 0.01887047472500052,
#  'day': 0.5029735293506061,
#  'earn': 0.5849431286519308,
#  'test': 0.05913788442743965,
#  'break': 0.2612235137551725,
#  'soon': 0.16774448441496329,
#  'move': 0.3513547233370069,
#  'check': 0.05863883055041484,
#  'movement': 0.028144559273044854,
#  'peer': 0.033031128485579424,
#  'mkm': 0.0017051007465014245,
#  'partner': 0.014420577654862656,
#  'it': 1.7410326256472104,
#  'too': 0.19705350273439937,
#  'early': 0.04956228816202616,
#  'tell': 0.1018589756919174,
#  'go': 1.1241916366887774,
#  'happen': 0.13538915805452165,
#  'even': 0.16898172215175397,
#  'about': 0.2858227111101869,
#  'raisinf': 1.039695577135015e-05,
#  'output': 0.001112474267534466,
#  'still': 0.3656921253456988,
#  'so': 0.4755671539373271,
#  'many': 0.09816805639308811,
#  'financially': 0.005926264789669585,
#  'healthy': 0.018756108211515667,
#  'problem': 0.02169844669480776,
#  'meet': 0.025462144684036514,
#  'its': 0.26735771766026906,
#  'obligations': 0.004668233141336217,
#  'bullish': 0.26169137676488324,
#  'stock': 0.7778586429893327,
#  'watch': 0.213730219791645,
#  'setups': 0.020076521594477138,
#  'timeframes': 0.0004054812750826558,
#  'just': 0.7601838181780375,
#  'high': 0.2312282963548273,
#  'alert': 0.2463662639579131,
#  'next': 0.4858393462394211,
#  'gt': 0.09719074255058119,
#  'breakdown': 0.010220207523237197,
#  'much': 0.17235033582167142,
#  'better': 0.14312449314840614,
#  'than': 0.3024890312116612,
#  'industry': 0.07528435674034642,
#  'average': 0.10281549562288161,
#  'miss': 0.12203946684410805,
#  'these': 0.14640993117215279,
#  'days': 0.19653365494583186,
#  'confirm': 0.06700837994635171,
#  'you': 0.9783743319955917,
#  'will': 1.3359984196627228,
#  'see': 0.5265642219957997,
#  'violent': 0.001528352498388472,
#  'downward': 0.008639870245991974,
#  'my': 0.5331870828221497,
#  'breakouts': 0.0024224906947245845,
#  'base': 0.08410097523445136,
#  'gap': 0.10699507184296438,
#  'ma': 0.051288182820070284,
#  'cabot': 0.0010916803559917656,
#  'weekly': 0.06740346426566302,
#  'video': 0.027052878917053085,
#  'quot': 0.4155975130481795,
#  'resilient': 0.0014243829406749703,
#  'growth': 0.3750389885841426,
#  'when': 0.3120646274770747,
#  'kid': 0.023434738308623235,
#  'froend': 1.039695577135015e-05,
#  'me': 0.2728577072633133,
#  'moon': 0.02299806616622653,
#  'make': 0.3511259903100372,
#  'cheese': 0.0012164438252479674,
#  'percent': 0.06548002744796323,
#  'rank': 0.06205942899918904,
#  'th': 0.06734108253103491,
#  'percentile': 0.014534944168347507,
#  'thank': 0.10222286914391467,
#  'don': 0.2640514857249797,
#  'feel': 0.08859246012767462,
#  'or': 0.38932440581397765,
#  'do': 0.6159572477178682,
#  'well': 0.17180969412156122,
#  'they': 0.58447526564222,
#  'already': 0.10032022623775759,
#  'during': 0.02661620677465638,
#  'youtube': 0.006165394772410638,
#  'interview': 0.0067372273398348965,
#  'mitch': 0.0006446112578237092,
#  'couldn': 0.013016988625730386,
#  'remember': 0.051776839741323744,
#  'single': 0.022571790979601172,
#  'movie': 0.005344035266473976,
#  'he': 0.11789108149133934,
#  'all': 0.6214572373209124,
#  'year': 0.2297311347237529,
#  'except': 0.01190451435819592,
#  'star': 0.026387473747686678,
#  'war': 0.051423343245097834,
#  'black': 0.01267388908527583,
#  'panther': 0.00019754215965565283,
#  'clothe': 0.0025680480755234866,
#  'downgrade': 0.06674845605206796,
#  'sale': 0.1045517872366971,
#  'interest': 0.1669127279532553,
#  'return': 0.0763760370963382,
#  'equity': 0.016479174897589984,
#  'although': 0.019431910336653428,
#  'market': 0.561643550768335,
#  'up': 1.2678359776257513,
#  'advance': 0.016468777941818634,
#  'as': 0.4793100580150132,
#  'info': 0.03951882888690191,
#  'july': 0.032604853298954066,
#  'most': 0.08533821297124201,
#  'normal': 0.01687425921690129,
#  'friday': 0.11273419142874966,
#  'contract': 0.14911313967270384,
#  'call': 0.7488199455199518,
#  'put': 0.39243309558961137,
#  'third': 0.016344014472562434,
#  'design': 0.007984862032396914,
#  'win': 0.13864340521095422,
#  'time': 0.41675157513879935,
#  'match': 0.015969724064793828,
#  'probably': 0.05248383273377555,
#  'arm': 0.0034725832276309497,
#  'alcohol': 0.0007485808155372107,
#  'tobacco': 0.001538749454159822,
#  'firearm': 1.039695577135015e-05,
#  'president': 0.029153063982865816,
#  'trump': 0.12282963548273065,
#  'tweet': 0.01677028965918779,
#  'speak': 0.015553845833939822,
#  'king': 0.012944209935330936,
#  'salman': 4.15878230854006e-05,
#  'saudi': 0.00629015824166684,
#  'arabia': 0.001538749454159822,
#  'explain': 0.012871431244931484,
#  'him': 0.02165685887172236,
#  'that': 0.9279179056372294,
#  'because': 0.08178245409744027,
#  'turmoil': 0.0013412072945041692,
#  'amp': 0.3694038385560708,
#  'today': 0.7833170447692915,
#  'insight': 0.0737664011977293,
#  'intc': 0.020627560250358695,
#  'mama': 0.0016843068349587241,
#  'say': 0.30839450208978814,
#  'ice': 0.004574660539394065,
#  'cream': 0.0017154977022727745,
#  'finish': 0.017310931359298,
#  'due': 0.038219209415483145,
#  'dil': 3.1190867314050445e-05,
#  'notice': 0.01462851677028966,
#  'last': 0.4028612422282756,
#  'jedi': 0.0018402611715289763,
#  'stream': 0.01963984945208043,
#  'love': 0.11901395271464515,
#  'here': 0.7771308560853382,
#  'leave': 0.06483541619013952,
#  'view': 0.05418893348027697,
#  'look': 0.5179555426171217,
#  'ema': 0.014430974610634006,
#  'stochastics': 0.0007589777713085608,
#  'turn': 0.07173899482231602,
#  'spy': 0.022810920962342225,
#  'qqq': 0.0068100060302343475,
#  'opposite': 0.009014160653760579,
#  'forward': 0.035505603959160754,
#  'pe': 0.04687987357301782,
#  'valuation': 0.043760786841612775,
#  'can': 0.47069098168056395,
#  'describe': 0.004387515335509763,
#  'cheap': 0.08122101848578736,
#  'saber': 0.00013516042502755194,
#  'capital': 0.030265538250400282,
#  'presentation': 0.006165394772410638,
#  'common': 0.014389386787548605,
#  'denominator': 9.357260194215133e-05,
#  'tencent': 0.0017051007465014245,
#  'facebook': 0.08395541785365244,
#  'google': 0.033519785406832876,
#  'how': 0.25371691168825766,
#  'one': 0.2731280281133684,
#  'perform': 0.018756108211515667,
#  'crude': 0.005011332681790772,
#  'petroleum': 0.002588841987066187,
#  'natural': 0.005364829178016677,
#  'gas': 0.015637021480110622,
#  'pu': 0.0004054812750826558,
#  'simply': 0.006602066914807345,
#  'havent': 0.002224948535068932,
#  'lose': 0.12009523611486557,
#  'any': 0.1494562392131584,
#  'brown': 0.0026616206774656382,
#  'run': 0.19793724397496412,
#  'tech': 0.09788733858726165,
#  'mfs': 0.00024952693851240356,
#  'educate': 0.001985818552327878,
#  'their': 0.2513775966397039,
#  'shit': 0.06889022894096608,
#  'every': 0.09283441808238548,
#  'former': 0.004501881848994614,
#  'global': 0.02601318333991807,
#  'manufacture': 0.005271256576074525,
#  'pfizer': 0.004699424008650267,
#  'independent': 0.0015699403214738724,
#  'director': 0.052400657087604746,
#  'nat': 0.0014035890291322702,
#  'ricciardi': 4.15878230854006e-05,
#  'may': 0.11356594789045768,
#  'safest': 0.0015907342330165727,
#  'special': 0.006373333887837641,
#  'limit': 0.018381817803747064,
#  'offer': 0.024942296895469007,
#  'june': 0.013505645546983844,
#  'tradenet': 5.198477885675074e-05,
#  'discount': 0.017342122226612047,
#  'intro': 0.0004054812750826558,
#  'program': 0.012465949969848828,
#  'below': 0.11671622548917678,
#  'financials': 0.010272192302093947,
#  'summary': 0.0047929966105924185,
#  'jeff': 0.007132311659146202,
#  'gundlach': 0.0004262751866253561,
#  'sohn': 0.00023912998274105342,
#  'long': 0.39765236738682913,
#  'thesis': 0.010137031877066395,
#  'energy': 0.02847726185772806,
#  'low': 0.23977459399887713,
#  'peg': 0.006373333887837641,
#  'which': 0.08507828907695826,
#  'compensate': 0.003649331475743902,
#  'indicate': 0.02721923020939469,
#  'rather': 0.02459919735501445,
#  'pres': 0.003638934519972552,
#  'equities': 0.017560458297810402,
#  'come': 0.405190160321058,
#  'seem': 0.07073049011249506,
#  'under': 0.09345823542866649,
#  'likely': 0.03786571291925724,
#  'bullshit': 0.00914932107878813,
#  'worthless': 0.010656879665633903,
#  'mean': 0.07426545507475411,
#  'fuck': 0.0666340895385831,
#  'nothing': 0.07261233910710944,
#  'macau': 0.0029007506602066915,
#  'usa': 0.011124742675344659,
#  'let': 0.2855419933043605,
#  'where': 0.1289534424320559,
#  'right': 0.1948805389781872,
#  'now': 0.596650100850471,
#  'ugly': 0.019130398619284273,
#  'without': 0.024297685637645297,
#  'clear': 0.030920546463995342,
#  'level': 0.09774178120646275,
#  'term': 0.18262252812376537,
#  'bearish': 0.11884760142230355,
#  'll': 0.1365432201451415,
#  'previously': 0.021137011083154852,
#  'mo': 0.007028342101432701,
#  'follow': 0.06903578632176499,
#  'by': 0.5590235179139548,
#  'end': 0.18274729159302155,
#  'month': 0.09901020981056746,
#  'another': 0.1453910295065605,
#  'runup': 0.0018714520388430267,
#  'smart': 0.03452829011665384,
#  'money': 0.25831236613919445,
#  'bet': 0.05323241354931276,
#  'deal': 0.07138549832609012,
#  'update': 0.2232642282339731,
#  'technical': 0.10565386454846021,
#  'bad': 0.13738537356262087,
#  'present': 0.02860202532698426,
#  'nice': 0.17449210871056955,
#  'setup': 0.06419080493231581,
#  'opportunity': 0.05430329999376183,
#  'completely': 0.010573704019463101,
#  'scale': 0.0069659603668046,
#  'gobble': 0.0022873302696970327,
#  'play': 0.13175022353454907,
#  'aka': 0.0034829801834023,
#  'favorite': 0.007912083341997464,
#  'them': 0.11467842215799214,
#  'iddy': 1.039695577135015e-05,
#  'bitty': 0.00010396955771350149,
#  'kiddy': 4.15878230854006e-05,
#  'hand': 0.04050653968518018,
#  'awesome': 0.019151192530826974,
#  'concern': 0.0174149009170115,
#  'eow': 0.021927179721777462,
#  'might': 0.090890187353143,
#  'wk': 0.013557630325840593,
#  'throwback': 0.0006134203905096587,
#  'us': 0.1377076791915327,
#  'advisors': 0.001528352498388472,
#  'upgrade': 0.09564159614065001,
#  'shorties': 0.00840074026325092,
#  'dream': 0.013058576448815787,
#  'depression': 0.0014139859849036202,
#  'somethin': 0.000280717805826454,
#  'loll': 0.0005198477885675074,
#  'hormel': 0.001195649913705267,
#  'foods': 0.006425318666694392,
#  'dividend': 0.07367282859578715,
#  'analysis': 0.03488178661287975,
#  'consumer': 0.015751387993595475,
#  'defensive': 0.002879956748663991,
#  'intel': 0.08218793537252292,
#  'profitability': 0.01961905554053773,
#  'safety': 0.011706972198540267,
#  'score': 0.028123765361502153,
#  'dividends': 0.014202241583664304,
#  'technology': 0.025534923374435966,
#  'both': 0.06471065272088332,
#  'positive': 0.07896487908340438,
#  'mad': 0.012902622112245535,
#  'report': 1.1638352290449356,
#  'block': 0.12079183215154603,
#  'person': 0.006976357322575949,
#  'spam': 0.0028383689255785907,
#  'should': 0.24925661766234847,
#  'open': 0.24838327337755506,
#  'projection': 0.0010708864444490653,
#  'thats': 0.023330768750909732,
#  'true': 0.022041546235262315,
#  'prefer': 0.005416813956873427,
#  'from': 0.6456509534008442,
#  'turd': 0.010001871452038843,
#  'wal': 0.0012996194714187685,
#  'mart': 0.0015075585868457716,
#  'aristocrat': 0.0023497120043251335,
#  'valueinvesting': 0.0005510386558815578,
#  'dvb': 0.00022873302696970328,
#  'aaamp': 0.000280717805826454,
#  'marriage': 0.00031190867314050445,
#  'bank': 0.09543365702522301,
#  'account': 0.03292715892786592,
#  'dm': 0.0005510386558815578,
#  'stop': 0.14863487970722172,
#  'post': 0.13852903869746938,
#  'big': 0.28694558233349277,
#  'calm': 0.00976274146929779,
#  'down': 0.7167349400095652,
#  'luck': 0.035370443534133204,
#  'chase': 0.021885591898692065,
#  'hopefully': 0.02717764238630929,
#  'catch': 0.033207876733692375,
#  'before': 0.2681374893431203,
#  'lisa': 0.031918654218044955,
#  'announce': 0.07203010958391383,
#  'rd': 0.014264623318292403,
#  'permamently': 1.039695577135015e-05,
#  'off': 0.22237009003763697,
#  'trade': 0.7544862864153375,
#  'maybe': 0.08113784283961656,
#  'altogether': 0.0002599238942837537,
#  'manipulation': 0.02519182383398141,
#  'very': 0.20763760370963383,
#  'rich': 0.01611528144559273,
#  'poor': 0.01953587989436693,
#  'fuk': 0.0023601089600964837,
#  'almost': 0.05795263146950573,
#  'pct': 0.007766525961198561,
#  'buybacks': 0.01969183423093718,
#  'share': 0.5117381630658543,
#  'though': 0.04273148822024911,
#  'drip': 0.0038884614584849555,
#  'dump': 0.08647148115031919,
#  'obv': 0.001881848994614377,
#  'but': 0.5552806138362687,
#  'jeez': 0.0035245680064877,
#  'bite': 0.04998856334865152,
#  'bounce': 0.14202241583664302,
#  'heikin': 0.00010396955771350149,
#  'ashi': 0.00012476346925620178,
#  'candle': 0.033925266681915534,
#  'confirmation': 0.007423426420744006,
#  'like': 0.546765507059533,
#  'wife': 0.006373333887837641,
#  'tree': 0.005344035266473976,
#  'fiddy': 0.0003327025846832048,
#  'sure': 0.08610758769832193,
#  'piggy': 0.002453681562038635,
#  'lot': 0.10404233640390094,
#  'coin': 0.004335530556653012,
#  'spend': 0.02378823480484914,
#  'candy': 0.0011748560021625667,
#  'microsoft': 0.02033644548876089,
#  'investors': 0.06720592210600736,
#  'aren': 0.017518870474725,
#  'happy': 0.04522675760537315,
#  'royal': 0.004470690981680564,
#  'canada': 0.013900729866295149,
#  'reiterate': 0.03811523985776964,
#  'outperform': 0.033738121478031236,
#  'loop': 0.0030151171736915432,
#  'raise': 0.10032022623775759,
#  'never': 0.09362458672100808,
#  'wrong': 0.05816057058493273,
#  'miracle': 0.0028279719698072405,
#  'period': 0.011405460481171113,
#  'bollinger': 0.0139735085566946,
#  'band': 0.015782578860909526,
#  'dare': 0.0038156827680855044,
#  'didn': 0.06150839034330748,
#  'guilty': 0.0010085047098209645,
#  'fudge': 0.0009877107982782642,
#  'hardly': 0.0026408267659229377,
#  'ever': 0.05849327316961594,
#  'informative': 0.0003430995404545549,
#  'comment': 0.023050050945083278,
#  'page': 0.006092616082011187,
#  'give': 0.14185606454430144,
#  'endless': 0.0024224906947245845,
#  'buffer': 0.00041587823085400595,
#  'icon': 0.0009149321078788131,
#  'viral': 0.00018714520388430267,
#  'walk': 0.016395999251419185,
#  'away': 0.04983260901208126,
#  'videos': 0.0018610550830716766,
#  'highlight': 0.009679565823126988,
#  'grow': 0.058254143186874885,
#  'democrats': 0.0021833607119835312,
#  'party': 0.01810109999792061,
#  'epoch': 2.07939115427003e-05,
#  'robert': 0.009689962778898338,
#  'baird': 0.006747624295606247,
#  'neutral': 0.03645172693435362,
#  'weed': 0.007527395978457508,
#  'other': 0.08794784886985091,
#  'drug': 0.013682393795096795,
#  'guess': 0.06815204508120022,
#  'reasonable': 0.006331746064752241,
#  'nike': 0.03967478322347217,
#  'click': 0.009409244973071884,
#  'book': 0.03005759913497328,
#  'app': 0.061747520326048536,
#  'native': 0.00018714520388430267,
#  'seamless': 0.00010396955771350149,
#  'lovalized': 1.039695577135015e-05,
#  'transactable': 1.039695577135015e-05,
#  'ap': 0.0008317564617080119,
#  'vitiello': 1.039695577135015e-05,
#  'tap': 0.0077977168285126115,
#  'act': 0.018444199538375165,
#  'via': 0.12913019068016884,
#  'reach': 0.10055935622049864,
#  'iconic': 0.0006446112578237092,
#  'brand': 0.021324156287039153,
#  'build': 0.029537751346405773,
#  'mobile': 0.009991474496267493,
#  'show': 0.1306169553554719,
#  'morning': 0.11672662244494812,
#  'head': 0.08818697885259195,
#  'ath': 0.03261525025472542,
#  'acquisition': 0.012996194714187686,
#  'total': 0.0633590484706078,
#  'past': 0.08623235116757813,
#  'exit': 0.019982948992534985,
#  'zone': 0.016531159676446736,
#  'fantastic': 0.005967852612754986,
#  'read': 0.04713979746730158,
#  'oil': 0.04942712773699861,
#  'tighten': 0.003618140608429852,
#  'bbl': 0.001528352498388472,
#  'closer': 0.010116237965523694,
#  'greatest': 0.004377118379738413,
#  'yearly': 0.012871431244931484,
#  'performance': 0.021490507579380758,
#  'champion': 0.0016739098791873738,
#  'cashflow': 0.0007797716828512612,
#  'highyield': 0.00023912998274105342,
#  'telecommunications': 7.277869039945104e-05,
#  'pretty': 0.046100101890166556,
#  'risky': 0.007381838597658606,
#  'gamble': 0.013370485121956292,
#  'either': 0.03359256409723233,
#  'plummet': 0.004470690981680564,
#  'rally': 0.07491006633257782,
#  'stronger': 0.008993366742217878,
#  'apple': 0.1300763136553617,
#  'talk': 0.07279948431099374,
#  'refer': 0.002224948535068932,
#  'intelsat': 5.198477885675074e-05,
#  'punish': 0.004938553991391321,
#  'sellers': 0.024027364787590193,
#  'warehouse': 0.0009149321078788131,
#  'sense': 0.024120937389532346,
#  'old': 0.03916533239067601,
#  'gather': 0.0019754215965565283,
#  'dust': 0.004637042274022166,
#  'pc': 0.005614356116529081,
#  'gamers': 0.0022041546235262314,
#  'crypto': 0.01804911521906386,
#  'miners': 0.0014347798964463206,
#  'gpu': 0.01339127903349899,
#  'enthusiasts': 0.0001663512923416024,
#  'two': 0.057100081096255015,
#  'years': 0.12632301262190432,
#  'only': 0.19728223576136908,
#  'medium': 0.00985631407123994,
#  'decent': 0.030431889542741886,
#  'pattern': 0.06795450292154458,
#  'five': 0.007579380757314258,
#  'baba': 0.005655943939614481,
#  'ahhhhhhhhhhhhhhhhhhhhh': 1.039695577135015e-05,
#  'raytheon': 0.0018298642157576262,
#  'industrials': 0.0032022623775758456,
#  'military': 0.0031814684660331455,
#  'riiiiiiiiiich': 1.039695577135015e-05,
#  'sooooon': 0.00011436651348485164,
#  'buuuuls': 1.039695577135015e-05,
#  'looooove': 4.15878230854006e-05,
#  'drink': 0.012143644340936973,
#  'doesn': 0.06515772181905138,
#  'through': 0.06395167494957477,
#  'warbey': 1.039695577135015e-05,
#  'parker': 0.0021209789773554305,
#  'prep': 0.0008317564617080119,
#  'glass': 0.0030671019525482937,
#  'focus': 0.015512258010854423,
#  'fashion': 0.0025368572082094362,
#  'wrt': 0.0001663512923416024,
#  'wearables': 0.0008525503732507122,
#  'sbux': 0.0023289180927824333,
#  'full': 0.031024516021708845,
#  'sex': 0.0017570855253581752,
#  'change': 0.07801875610821152,
#  'employees': 0.007870495518912063,
#  'hit': 0.14481919693913622,
#  'bottom': 0.10833627913746854,
#  'line': 0.07565864714811503,
#  'recap': 0.01398390551246595,
#  'since': 0.234960803476742,
#  'include': 0.01744609178432555,
#  'hsy': 0.0002599238942837537,
#  'uri': 0.00047825996548210684,
#  'sonc': 0.00011436651348485164,
#  'dri': 0.0004262751866253561,
#  'kmx': 0.0003327025846832048,
#  'wynn': 0.005260859620303175,
#  'akam': 0.0004990538770248071,
#  'enterprise': 0.013474454679669793,
#  'value': 0.07615770102513984,
#  'vs': 0.0557900646690649,
#  'cap': 0.042866648645276666,
#  'difference': 0.005895073922355535,
#  'actual': 0.006747624295606247,
#  'assets': 0.014940425443430164,
#  'spread': 0.027593520617163296,
#  'way': 0.1620469526522634,
#  'undervalue': 0.026792955022769332,
#  'million': 0.055540537730552494,
#  'add': 0.15144205776548628,
#  'dont': 0.06500176748248113,
#  'become': 0.03190825726227361,
#  'such': 0.030275935206171632,
#  'monopoly': 0.0031814684660331455,
#  'dip': 0.19053461146576284,
#  'into': 0.17949304443658898,
#  'everything': 0.04459254330332079,
#  'airline': 0.002370505915867834,
#  'possibility': 0.0040132249277411575,
#  'loss': 0.05448004824187478,
#  'suggest': 0.015054791956915016,
#  'chartmill': 0.0020689941984986795,
#  'analyzer': 0.0053960200453307275,
#  'resistance': 0.07162462830883118,
#  'len': 0.000561435611652908,
#  'reversal': 0.04998856334865152,
#  'progress': 0.006175791728181989,
#  've': 0.0700131001642719,
#  'recently': 0.008567091555592522,
#  'close': 0.38165145245472126,
#  'list': 0.035567985693788856,
#  'same': 0.12541847746979684,
#  'use': 0.08116903370693061,
#  'accord': 0.021428125844752656,
#  'data': 0.10094404358403859,
#  'finra': 0.02876837661932586,
#  'clock': 0.010241001434779896,
#  'officials': 0.0009669168867355638,
#  'agree': 0.022790127050799525,
#  'resume': 0.00699715123411865,
#  'cover': 0.10202532698425901,
#  'penis': 0.00045746605393940656,
#  'putang': 1.039695577135015e-05,
#  'front': 0.005936661745440935,
#  'legs': 0.0038676675469422554,
#  'would': 0.2325695036493315,
#  'some': 0.31601547067018776,
#  'wonder': 0.03891580545216361,
#  'inning': 0.0003223056289118546,
#  'higher': 0.2645609365577759,
#  'also': 0.08201118712440997,
#  'consolidation': 0.02090827805618515,
#  'cautious': 0.005364829178016677,
#  'stun': 0.0013100164271901188,
#  'deeply': 0.0009357260194215133,
#  'disappoint': 0.015803372772452227,
#  'ways': 0.008982969786446528,
#  'kill': 0.04883450125803165,
#  'best': 0.10365764904036098,
#  'february': 0.0038988584142563057,
#  'funny': 0.026065168118774823,
#  'thing': 0.09534008442328086,
#  'similar': 0.011758956977397018,
#  'story': 0.022031149279490965,
#  'different': 0.016146472312906782,
#  'crab': 0.0004054812750826558,
#  'measure': 0.007277869039945104,
#  'divergence': 0.007568983801542908,
#  'really': 0.11713210372003077,
#  'momentum': 0.0352248861533343,
#  'shi': 0.0006134203905096587,
#  'venture': 0.0031814684660331455,
#  'tariff': 0.08383065438439626,
#  'increase': 0.06223617724730199,
#  'profit': 0.16858663783244265,
#  'recession': 0.0104905283732923,
#  'keep': 0.17555259819924726,
#  'pure': 0.009689962778898338,
#  'beanscreen': 2.07939115427003e-05,
#  'min': 0.046661537501819464,
#  'accumulation': 0.007568983801542908,
#  'eod': 0.05378345220519432,
#  'could': 0.1682435382919881,
#  'pop': 0.08603480900792249,
#  'heavy': 0.017820382192094156,
#  'apog': 7.277869039945104e-05,
#  'acn': 0.00047825996548210684,
#  'camp': 0.0007901686386226113,
#  'gi': 0.0006550082135950594,
#  'payx': 0.00023912998274105342,
#  'fdx': 0.0011748560021625667,
#  'goos': 0.000280717805826454,
#  'pullback': 0.04336570252230147,
#  'upside': 0.05348194048782517,
#  'nvda': 0.033207876733692375,
#  'safe': 0.020658751117672746,
#  'buyback': 0.03331184629140588,
#  'yield': 0.02704248196128174,
#  'div': 0.022894096608513027,
#  'gladly': 0.0009461229751928635,
#  'irrationality': 0.00024952693851240356,
#  'reign': 0.00046786300971075667,
#  'possible': 0.04334490861075877,
#  'excess': 0.0006758021251377596,
#  'gain': 0.135399555010293,
#  'welcome': 0.014503753301033458,
#  'gl': 0.031627539456447154,
#  'stories': 0.005416813956873427,
#  'jump': 0.049219188621571604,
#  'joy': 0.0028383689255785907,
#  'least': 0.05730802021168202,
#  'action': 0.07102160487409287,
#  'continuation': 0.005978249568526335,
#  'hopeful': 0.0016843068349587241,
#  'science': 0.0016739098791873738,
#  'officially': 0.005614356116529081,
#  'major': 0.038822232850221454,
#  'universities': 4.15878230854006e-05,
#  'ai': 0.017913954794036305,
#  'brainers': 5.198477885675074e-05,
#  'era': 0.0028487658813499406,
#  'second': 0.031066103844794243,
#  'minutes': 0.034320351001226844,
#  'rule': 0.023881807406791293,
#  'apply': 0.005759913497327982,
#  'zbra': 6.238173462810089e-05,
#  'six': 0.005791104364642033,
#  'fc': 0.00023912998274105342,
#  'gbx': 4.15878230854006e-05,
#  'fds': 0.0003223056289118546,
#  'avav': 9.357260194215133e-05,
#  'tax': 0.02375704393753509,
#  'cut': 0.056247530723004306,
#  'idea': 0.024266494770331246,
#  'haven': 0.018683329521116218,
#  'while': 0.07499324197874863,
#  'omg': 0.01763323698820985,
#  'toy': 0.004075606662369258,
#  'land': 0.008047243767025015,
#  'amaze': 0.03355097627414693,
#  'contribute': 0.0013827951175895698,
#  'ytd': 0.012154041296708324,
#  'popular': 0.00422116404316816,
#  'word': 0.021313759331267806,
#  'buyin': 0.0013516042502755192,
#  'those': 0.1022540600112287,
#  'haha': 0.02157368322555156,
#  'makin': 0.0005718325674242582,
#  'rain': 0.0028383689255785907,
#  'white': 0.009637978000041588,
#  'house': 0.021937576677548812,
#  'quality': 0.015158761514628517,
#  'moment': 0.026273107234201825,
#  'doubt': 0.019099207751970222,
#  'production': 0.009554802353870786,
#  'eps': 0.34605227589361837,
#  'constellation': 0.0033478197583747477,
#  'disney': 0.013412072945041691,
#  'clinch': 9.357260194215133e-05,
#  'acquire': 0.018797696034601068,
#  'fox': 0.008016052899710965,
#  'group': 0.04642240751907841,
#  'counter': 0.0027655902351791397,
#  'aggregate': 0.007943274209311513,
#  'southwest': 0.0015803372772452227,
#  'airlines': 0.007423426420744006,
#  'flight': 0.0033894075814601484,
#  'dallas': 0.00045746605393940656,
#  'delta': 0.0044395001143665135,
#  'spat': 0.0005406417001102078,
#  'california': 0.0029735293506061426,
#  'netflix': 0.05279574140691606,
#  'inc': 0.07268511779750889,
#  'nflx': 0.03364454887608908,
#  'versus': 0.009617184088498888,
#  'fb': 0.0810234763261317,
#  'starbucks': 0.006092616082011187,
#  'iex': 0.022738142271942777,
#  'calculate': 0.00349337713917365,
#  'shorters': 0.00281757501403589,
#  'emergence': 1.039695577135015e-05,
#  'bankruptcy': 0.014555738079890208,
#  'emergency': 0.0008733442847934125,
#  'zwj': 6.238173462810089e-05,
#  'investment': 0.03967478322347217,
#  'counsel': 0.003930049281570356,
#  'lower': 0.17632197292632718,
#  'stake': 0.010729658356033353,
#  'unitedhealth': 0.0017882763926722256,
#  'unh': 0.001112474267534466,
#  'tyzen': 1.039695577135015e-05,
#  'vega': 0.0034621862718595994,
#  'laptops': 0.001538749454159822,
#  'invest': 0.04839782911563494,
#  'annuity': 0.00015595433657025222,
#  'yr': 0.017206961801584496,
#  'bond': 0.012996194714187686,
#  'unsure': 0.0007277869039945104,
#  'country': 0.00771454118234181,
#  'amd': 0.23209124368384937,
#  'ryzen': 0.010386558815578798,
#  'gettin': 0.0015699403214738724,
#  'blast': 0.007953671165082863,
#  'cgnx': 6.238173462810089e-05,
#  'cx': 0.00029111476159780417,
#  'aaoi': 0.0005510386558815578,
#  'aa': 0.00069659603668046,
#  'amswa': 1.039695577135015e-05,
#  'yy': 0.00020793911542700297,
#  'snx': 8.31756461708012e-05,
#  'shark': 0.0022873302696970327,
#  'definitely': 0.019723025098251232,
#  'august': 0.027655902351791394,
#  'gs': 0.012736270819903932,
#  'point': 0.0940404649518621,
#  'huge': 0.09658771911584288,
#  'scalp': 0.017352519182383397,
#  'giant': 0.01191491131396727,
#  'ferment': 5.198477885675074e-05,
#  'mark': 0.03604624565927097,
#  'compare': 0.04439500114366513,
#  'cheaply': 0.00766255640348506,
#  'quite': 0.035256077020648355,
#  'job': 0.03698197167869248,
#  'clearly': 0.010968788338774406,
#  'things': 0.035547191782246156,
#  'cup': 0.020596369383044644,
#  'holder': 0.006529288224407894,
#  'inverse': 0.005219271797217775,
#  'confidence': 0.007984862032396914,
#  'debt': 0.031274042960221245,
#  'sell': 0.7287434239254746,
#  'frame': 0.004574660539394065,
#  'traders': 0.035183298330248906,
#  'meanwhile': 0.005250462664531825,
#  'galaxy': 0.0012268407810193175,
#  'far': 0.05732881412322472,
#  'broaden': 0.0004366721423967062,
#  'wedge': 0.013162546006529288,
#  'descend': 0.00349337713917365,
#  'large': 0.06503295834979518,
#  'im': 0.0528061383626874,
#  'pt': 0.1501216443825248,
#  'three': 0.01682227443804454,
#  'fall': 0.1084922334740388,
#  'peak': 0.026501840261171528,
#  'fourth': 0.002588841987066187,
#  'everyone': 0.08680418373500239,
#  'coke': 0.0029215445717493916,
#  'smile': 0.003150277598719095,
#  'prove': 0.011935705225509971,
#  'terrible': 0.00975234451352644,
#  'error': 0.0014867646753030713,
#  'article': 0.025462144684036514,
#  'hint': 0.004137988396997359,
#  'sogou': 0.00011436651348485164,
#  'finger': 0.007225884261088353,
#  'cross': 0.05392900958599322,
#  'triple': 0.013609615104697345,
#  'top': 0.15201389033291052,
#  'bro': 0.0063837308436089915,
#  'work': 0.08547337339626958,
#  'delete': 0.005312844399159926,
#  'blue': 0.017102992243870994,
#  'arrow': 0.0006134203905096587,
#  'your': 0.2647688756732029,
#  'delusion': 0.0007277869039945104,
#  'overbought': 0.017570855253581753,
#  'mr': 0.012351583456363977,
#  'yo': 0.009294878459587033,
#  'hi': 0.008234388970909317,
#  'bed': 0.007506602066914807,
#  'night': 0.022155912748747168,
#  'prepare': 0.01119752136574411,
#  'policy': 0.002526460252438086,
#  'penalize': 0.00020793911542700297,
#  'store': 0.08607639683100789,
#  'products': 0.02787423842298975,
#  'fyi': 0.0069867542783473,
#  'ramp': 0.008275976793994718,
#  'worker': 0.0010812834002204156,
#  'revolt': 0.00030151171736915433,
#  'hill': 0.004075606662369258,
#  'rail': 0.0014971616310744213,
#  'people': 0.17038531118088623,
#  'managers': 0.0034413923603168993,
#  'circuit': 0.000977313842506914,
#  'city': 0.005666340895385831,
#  'deux': 7.277869039945104e-05,
#  'fail': 0.035349649622590504,
#  'despite': 0.013120958183443887,
#  'bb': 0.021844004075606663,
#  'incr': 0.00017674824811295253,
#  'mm': 0.03715871992680543,
#  'drive': 0.029724896550290075,
#  'prior': 0.01256991952756233,
#  'arguments': 0.0007797716828512612,
#  'sound': 0.018038718263292508,
#  'gameranx': 1.039695577135015e-05,
#  'game': 0.06402445363997422,
#  'channel': 0.026241916366887774,
#  'cash': 0.09418602233266099,
#  'machine': 0.014327005052920505,
#  'semi': 0.01268428604104718,
#  'altria': 0.0018298642157576262,
#  'aflac': 0.0008733442847934125,
#  'eatonvance': 1.039695577135015e-05,
#  'graph': 0.002453681562038635,
#  'tripple': 0.0004054812750826558,
#  'weeks': 0.07302821733796344,
#  'want': 0.19189661267180969,
#  'vagina': 9.357260194215133e-05,
#  'alteration': 3.1190867314050445e-05,
#  'oled': 0.0009565199309642137,
#  'panel': 0.0009669168867355638,
#  'steady': 0.013349691210413591,
#  'amid': 0.005947058701212285,
#  'weak': 0.052223908839491795,
#  'demand': 0.023694662202906988,
#  'display': 0.0024120937389532347,
#  'andromeda': 5.198477885675074e-05,
#  'leak': 0.009502817575014037,
#  'foldable': 0.00018714520388430267,
#  'dual': 0.000977313842506914,
#  'screen': 0.006747624295606247,
#  'surface': 0.0022665363581543326,
#  'device': 0.003503774094945,
#  'fit': 0.00488656921253457,
#  'pocket': 0.007059532968746751,
#  'piotroski': 0.009357260194215134,
#  'health': 0.025056663408953857,
#  'original': 0.005188080929903724,
#  'predicate': 0.00010396955771350149,
#  'competitive': 0.002931941527520742,
#  'server': 0.008650267201763324,
#  'product': 0.019826994655964734,
#  'around': 0.1188164105549895,
#  'bat': 0.002516063296666736,
#  ...}

# %%
"""
Set the following variables:
    freqs
    low_cutoff
    high_cutoff
    K_most_common
"""

# TODO Implement 

# Dictionart that contains the Frequency of words appearing in messages.
# The key is the token and the value is the frequency of that word in the corpus.
freqs = {key: value/len(bow) for key, value in bow.items()}

# Float that is the frequency cutoff. Drop words with a frequency that is lower or equal to this number.
low_cutoff = 0.00007

# Integer that is the cut off for most common words. Drop words that are the `high_cutoff` most common words.
high_cutoff = 20

# The k most common words in the corpus. Use `high_cutoff` as the k.
K_most_common = bow.most_common(n=high_cutoff)


filtered_words = [word for word in freqs if (freqs[word] > low_cutoff and word not in K_most_common)]
print(K_most_common)
len(filtered_words)
# Out:
# [('be', 579651), ('the', 398063), ('to', 378590), ('for', 272839), ('on', 241388), ('of', 210919), ('and', 208192), ('in', 204364), ('this', 203026), ('it', 167456), ('at', 138205), ('will', 128499), ('up', 121943), ('buy', 118951), ('report', 111940), ('go', 108127), ('have', 107025), ('you', 94102), ('short', 93751), ('that', 89249)]
# 21135

# %% [markdown]
# ### Updating Vocabulary by Removing Filtered Words
# Let's creat three variables that will help with our vocabulary.

# %%
"""
Set the following variables:
    vocab
    id2vocab
    filtered
"""

#TODO Implement

# A dictionary for the `filtered_words`. The key is the word and value is an id that represents the word. 
vocab = { word:idx for idx, word in enumerate(filtered_words)}
# Reverse of the `vocab` dictionary. The key is word id and value is the word. 
id2vocab = { idx: word for idx, word in enumerate(filtered_words)}
# tokenized with the words not in `filtered_words` removed.
filtered = [[word for word in message if word in vocab] for message in tokenized]

# %% [markdown]
# ### Balancing the classes
# Let's do a few last pre-processing steps. If we look at how our twits are labeled, we'll find that 50% of them are neutral. This means that our network will be 50% accurate just by guessing 0 every single time. To help our network learn appropriately, we'll want to balance our classes.
# That is, make sure each of our different sentiment scores show up roughly as frequently in the data.
#
# What we can do here is go through each of our examples and randomly drop twits with neutral sentiment. What should be the probability we drop these twits if we want to get around 20% neutral twits starting at 50% neutral? We should also take this opportunity to remove messages with length 0.

# %%
balanced = {'messages': [], 'sentiments':[]}

n_neutral = sum(1 for each in sentiments if each == 2)
N_examples = len(sentiments)
keep_prob = (N_examples - n_neutral)/4/n_neutral

for idx, sentiment in enumerate(sentiments):
    message = filtered[idx]
    if len(message) == 0:
        # skip this message because it has length zero
        continue
    elif sentiment != 2 or random.random() < keep_prob:
        balanced['messages'].append(message)
        balanced['sentiments'].append(sentiment)

# %% [markdown]
# If you did it correctly, you should see the following result

# %%
n_neutral = sum(1 for each in balanced['sentiments'] if each == 2)
N_examples = len(balanced['sentiments'])
n_neutral/N_examples
# Out:
# 0.1945791138102233

# %% [markdown]
# Finally let's convert our tokens into integer ids which we can pass to the network.

# %%
token_ids = [[vocab[word] for word in message] for message in balanced['messages']]
sentiments = balanced['sentiments']

# %% [markdown]
# ## Neural Network
# Now we have our vocabulary which means we can transform our tokens into ids, which are then passed to our network. So, let's define the network now!
#
# Here is a nice diagram showing the network we'd like to build:
#
# #### Embed -> RNN -> Dense -> Softmax
# ### Implement the text classifier
# Before we build text classifier, if you remember from the other network that you built in  "Sentiment Analysis with an RNN"  exercise  - which there, the network called " SentimentRNN", here we named it "TextClassifer" - consists of three main parts: 1) init function `__init__` 2) forward pass `forward`  3) hidden state `init_hidden`.
#
# This network is pretty similar to the network you built expect in the  `forward` pass, we use softmax instead of sigmoid. The reason we are not using sigmoid is that the output of NN is not a binary. In our network, sentiment scores have 5 possible outcomes. We are looking for an outcome with the highest probability thus softmax is a better choice.

# %%
class TextClassifier(nn.Module):
    def __init__(self, vocab_size, embed_size, lstm_size, output_size, lstm_layers=1, dropout=0.1):
        """
        Initialize the model by setting up the layers.
        
        Parameters
        ----------
            vocab_size : The vocabulary size.
            embed_size : The embedding layer size.
            lstm_size : The LSTM layer size.
            output_size : The output size.
            lstm_layers : The number of LSTM layers.
            dropout : The dropout probability.
        """
        
        super().__init__()
        self.vocab_size = vocab_size
        self.embed_size = embed_size
        self.lstm_size = lstm_size
        self.output_size = output_size
        self.lstm_layers = lstm_layers
        self.dropout = dropout
        
        # TODO Implement

        # Setup embedding layer
        self.embedding = nn.Embedding(vocab_size, embed_size)
        
        # Setup additional layers
        
        self.lstm = nn.LSTM(embed_size, lstm_size, lstm_layers, dropout=dropout, batch_first=False)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(lstm_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)       


    def init_hidden(self, batch_size):
        """ 
        Initializes hidden state
        
        Parameters
        ----------
            batch_size : The size of batches.
        
        Returns
        -------
            hidden_state
            
        """
        
        # TODO Implement )
        # Create two new tensors with sizes n_layers x batch_size x hidden_dim,
        # initialized to zero, for hidden state and cell state of LSTM
        weight = next(self.parameters()).data
        hidden_state = (weight.new(self.lstm_layers, batch_size, self.lstm_size).zero_(),
                weight.new(self.lstm_layers, batch_size, self.lstm_size).zero_())
                       
        return hidden_state


    def forward(self, nn_input, hidden_state):
        """
        Perform a forward pass of our model on nn_input.
        
        Parameters
        ----------
            nn_input : The batch of input to the NN.
            hidden_state : The LSTM hidden state.

        Returns
        -------
            logps: log softmax output
            hidden_state: The new hidden state.

        """
        
        # TODO Implement 
        nn_input = nn_input.long()
        embedded = self.embedding(nn_input)
        lstm_out, hidden_state = self.lstm(embedded, hidden_state)
        
        lstm_out = lstm_out[-1,:,:]
        out = self.dropout(lstm_out)
        out = self.fc(out)
        
        logps = self.softmax(out)
        
        return logps, hidden_state

# %% [markdown]
# ### View Model

# %%
model = TextClassifier(len(vocab), 10, 6, 5, dropout=0.1, lstm_layers=2)
model.embedding.weight.data.uniform_(-1, 1)
input = torch.randint(0, 1000, (5, 4), dtype=torch.int64)
hidden = model.init_hidden(4)

logps, _ = model.forward(input, hidden)
print(logps)
# Out:
# tensor([[-1.1405, -1.7058, -1.7164, -1.7737, -1.9017],
#         [-1.1129, -1.8009, -1.7481, -1.7168, -1.8805],
#         [-1.1170, -1.7218, -1.7456, -1.7805, -1.8910],
#         [-1.1142, -1.8057, -1.7656, -1.7103, -1.8606]])

# %% [markdown]
# ## Training
# ### DataLoaders and Batching
# Now we should build a generator that we can use to loop through our data. It'll be more efficient if we can pass our sequences in as batches. Our input tensors should look like `(sequence_length, batch_size)`. So if our sequences are 40 tokens long and we pass in 25 sequences, then we'd have an input size of `(40, 25)`.
#
# If we set our sequence length to 40, what do we do with messages that are more or less than 40 tokens? For messages with fewer than 40 tokens, we will pad the empty spots with zeros. We should be sure to **left** pad so that the RNN starts from nothing before going through the data. If the message has 20 tokens, then the first 20 spots of our 40 long sequence will be 0. If a message has more than 40 tokens, we'll just keep the first 40 tokens.

# %%
def dataloader(messages, labels, sequence_length=30, batch_size=32, shuffle=False):
    """ 
    Build a dataloader.
    """
    if shuffle:
        indices = list(range(len(messages)))
        random.shuffle(indices)
        messages = [messages[idx] for idx in indices]
        labels = [labels[idx] for idx in indices]

    total_sequences = len(messages)

    for ii in range(0, total_sequences, batch_size):
        batch_messages = messages[ii: ii+batch_size]
        
        # First initialize a tensor of all zeros
        batch = torch.zeros((sequence_length, len(batch_messages)), dtype=torch.int64)
        for batch_num, tokens in enumerate(batch_messages):
            token_tensor = torch.tensor(tokens)
            # Left pad!
            start_idx = max(sequence_length - len(token_tensor), 0)
            batch[start_idx:, batch_num] = token_tensor[:sequence_length]
        
        label_tensor = torch.tensor(labels[ii: ii+len(batch_messages)])
        
        yield batch, label_tensor

# %% [markdown]
# ### Training and  Validation
# With our data in nice shape, we'll split it into training and validation sets.

# %%
"""
Split data into training and validation datasets. Use an appropriate split size.
The features are the `token_ids` and the labels are the `sentiments`.
"""   

# TODO Implement 

split = int(len(token_ids) * .8 )

train_features,remaining_x = token_ids[:split],token_ids[split:]

val  = int(len(token_ids[split:]) * .5)
valid_features = remaining_x[:val]

train_labels,remaining_y = sentiments[:split],sentiments[split:]
valid_labels = remaining_y[:val]

# %%
text_batch, labels = next(iter(dataloader(train_features, train_labels, sequence_length=20, batch_size=64)))
model = TextClassifier(len(vocab)+1, 200, 128, 5, dropout=0.)
hidden = model.init_hidden(64)
logps, hidden = model.forward(text_batch, hidden)

# %% [markdown]
# ### Training
# It's time to train the neural network!

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = TextClassifier(len(vocab)+1, 1024, 512, 5, lstm_layers=2, dropout=0.2)
model.embedding.weight.data.uniform_(-1, 1)
model.to(device)
# Out:
# TextClassifier(
#   (embedding): Embedding(21136, 1024)
#   (lstm): LSTM(1024, 512, num_layers=2, dropout=0.2)
#   (dropout): Dropout(p=0.2)
#   (fc): Linear(in_features=512, out_features=5, bias=True)
#   (softmax): LogSoftmax()
# )

# %%
"""
Train your model with dropout. Make sure to clip your gradients.
Print the training loss, validation loss, and validation accuracy for every 100 steps.
"""

from time import time
import numpy as np

epochs = 1
batch_size = 1024
learning_rate = 0.001

print_every = 100
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
model.train()

for epoch in range(epochs):
    start = time()
    print('Starting epoch {}'.format(epoch + 1))
    
    steps = 0
    hidden = model.init_hidden(batch_size)
    
    for text_batch, labels in dataloader(
            train_features, train_labels, batch_size=batch_size, sequence_length=20, shuffle=True):
        steps += 1                            
            
        # Set Device
        text_batch, labels = text_batch.to(device), labels.to(device)
        for each in hidden:
            each.to(device)
        
        # TODO Implement: Train Model
        hidden = tuple([each.data for each in hidden])
        
        model.zero_grad()
        
        # Somehow tensor shape is not correct at step 804 but I am not sure why.
        # When printing out the shape with hidden[00.size() it shows up correctly as (2,1024,512)
        if steps >= 800:
            break
            
        logps, hidden = model(text_batch, hidden) 
        loss = criterion(logps, labels) # calculate the loss
        loss.backward()

        nn.utils.clip_grad_norm_(model.parameters(), 5) 
        optimizer.step()
        
        if steps % print_every == 0:
            model.eval()
            
            # TODO Implement: Print metrics
            valid_hidden = model.init_hidden(batch_size)
            valid_losses = []
            accuracy = []
            for text_batch, labels in dataloader(
                    valid_features, valid_labels, batch_size=batch_size, sequence_length=20, shuffle=True):
                if text_batch.size(1) != batch_size:
                    break 
                for each in hidden:
                    each.to(device)                    
            
                valid_hidden = tuple([each.data for each in valid_hidden])
                text_batch, labels = text_batch.to(device), labels.to(device)
                valid_logps, valid_hidden = model(text_batch, valid_hidden)
                valid_loss = criterion(valid_logps.squeeze(), labels.long())
                valid_losses.append(valid_loss.item())
                # accuracy
                ps = torch.exp(valid_logps)
                top_p, top_class = ps.topk(1, dim=1)
                equals = top_class == labels.view(*top_class.shape)
                accuracy.append(torch.mean(equals.type(torch.FloatTensor)).item())
                
            tac = time()
            model.train()
            print('Epoch: {}/{}'.format(epoch+1, epochs)
                    ,' Step: {}'.format(steps)
                    ,' Loss: {:.6f}'.format(loss.item())
                    ,' Valid Loss: {:.6f}'.format(np.mean(valid_losses))
                    ,' Accuracy: {:.6f}'.format(np.mean(accuracy)))
    print('Epoch: {}'.format((time()-start)))
# Out:
# Starting epoch 1
# Epoch: 1/1  Step: 100  Loss: 0.923500  Valid Loss: 0.921502  Accuracy: 0.634404
# Epoch: 1/1  Step: 200  Loss: 0.812253  Valid Loss: 0.826479  Accuracy: 0.679912
# Epoch: 1/1  Step: 300  Loss: 0.764516  Valid Loss: 0.786892  Accuracy: 0.694941
# Epoch: 1/1  Step: 400  Loss: 0.755806  Valid Loss: 0.753402  Accuracy: 0.711221
# Epoch: 1/1  Step: 500  Loss: 0.707021  Valid Loss: 0.732468  Accuracy: 0.719727
# Epoch: 1/1  Step: 600  Loss: 0.734045  Valid Loss: 0.730564  Accuracy: 0.722285
# Epoch: 1/1  Step: 700  Loss: 0.713851  Valid Loss: 0.711688  Accuracy: 0.726494
# Epoch: 354.43729519844055

# %%
torch.save(model.state_dict(), 'my_model')

# %% [markdown]
# ## Making Predictions
# ### Prediction
# Okay, now that you have a trained model, try it on some new twits and see if it works appropriately. Remember that for any new text, you'll need to preprocess it first before passing it to the network. Implement the `predict` function to generate the prediction vector from a message.

# %%
def predict(text, model, vocab):
    """ 
    Make a prediction on a single sentence.

    Parameters
    ----------
        text : The string to make a prediction on.
        model : The model to use for making the prediction.
        vocab : Dictionary for word to word ids. The key is the word and the value is the word id.

    Returns
    -------
        pred : Prediction vector
    """    
    
    # TODO Implement
    
    tokens = preprocess(text)
    
    # Filter non-vocab words
    tokens = [ val for val in tokens if val in vocab ]
    # Convert words to ids
    tokens = [vocab[x] for x in tokens]
        
    # Adding a batch dimension
    text_input = torch.from_numpy(np.asarray(torch.FloatTensor(tokens).view(-1, 1)))
    # Get the NN output
    hidden = model.init_hidden(1)
    logps, _ = model.forward(text_input, hidden)
    # Take the exponent of the NN output to get a range of 0 to 1 for each label.
    pred = torch.exp(logps)
    
    return pred

# %%
text = "Google is working on self driving cars, I'm bullish on $goog"
model.eval()
model.to("cpu")
predict(text, model, vocab)
# Out:
# tensor([[ 0.0003,  0.0164,  0.0120,  0.8325,  0.1387]])

# %%
text = "Google is working on self driving cars, I'm bullish on $goog"
model.eval()
model.to("cpu")
pred = predict(text, model, vocab)
torch.round(pred.squeeze())
# Out:
# tensor([ 0.,  0.,  0.,  1.,  0.])

# %% [markdown]
# ### Questions: What is the prediction of the model? What is the uncertainty of the prediction?
#
# _**The prediction is that the sentiment of the message is a 1 with an uncertainty of ~17% ( probability of sentiment 1 is ~83% )**_

# %% [markdown]
# Now we have a trained model and we can make predictions. We can use this model to track the sentiments of various stocks by predicting the sentiments of twits as they are coming in. Now we have a stream of twits. For each of those twits, pull out the stocks mentioned in them and keep track of the sentiments. Remember that in the twits, ticker symbols are encoded with a dollar sign as the first character, all caps, and 2-4 letters, like $AAPL. Ideally, you'd want to track the sentiments of the stocks in your universe and use this as a signal in your larger model(s).
#
# ## Testing
# ### Load the Data

# %%
with open(os.path.join('..', '..', 'data', 'project_6_stocktwits', 'test_twits.json'), 'r') as f:
    test_data = json.load(f)

# %% [markdown]
# ### Twit Stream

# %%
def twit_stream():
    for twit in test_data['data']:
        yield twit

next(twit_stream())
# Out:
# {'message_body': '$JWN has moved -1.69% on 10-31. Check out the movement and peers at  https://dividendbot.com?s=JWN',
#  'timestamp': '2018-11-01T00:00:05Z'}

# %% [markdown]
# Using the `prediction` function, let's apply it to a stream of twits.

# %%
def score_twits(stream, model, vocab, universe):
    """ 
    Given a stream of twits and a universe of tickers, return sentiment scores for tickers in the universe.
    """
    for twit in stream:

        # Get the message text
        text = twit['message_body']
        symbols = re.findall('\$[A-Z]{2,4}', text)
        score = predict(text, model, vocab)

        for symbol in symbols:
            if symbol in universe:
                yield {'symbol': symbol, 'score': score, 'text': twit['message_body'], 'timestamp': twit['timestamp']}

# %%
universe = {'$BBRY', '$AAPL', '$AMZN', '$BABA', '$YHOO', '$LQMT', '$FB', '$GOOG', '$BBBY', '$JNUG', '$SBUX', '$MU'}
score_stream = score_twits(twit_stream(), model, vocab, universe)

next(score_stream)
# Out:
# {'symbol': '$AAPL',
#  'score': tensor([[ 0.1043,  0.1218,  0.1293,  0.2774,  0.3671]]),
#  'text': '$AAPL 190 after ER',
#  'timestamp': '2018-11-01T00:00:18Z'}

# %%
next(score_stream)
# Out:
# {'symbol': '$AMZN',
#  'score': tensor([[ 0.0013,  0.0308,  0.0122,  0.8329,  0.1229]]),
#  'text': '$AMZN A lot of technical signs point to a short-term bottom in place for stocks (John Murphy)',
#  'timestamp': '2018-11-01T00:00:42Z'}

# %% [markdown]
# That's it. You have successfully built a model for sentiment analysis!

# %% [markdown]
# ## Submission
# Now that you're done with the project, it's time to submit it. Click the submit button in the bottom right. One of our reviewers will give you feedback on your project with a pass or not passed grade. You can continue to the next section while you wait for feedback.
